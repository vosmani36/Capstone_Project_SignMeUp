# %% [markdown]
# # Real-Time Prediction

# %% [markdown]
# ## Reference

# %% [markdown]
# The code in this notebook is adapted and modified from the following Youtube tutorial: https://www.youtube.com/watch?v=doDUihpj6ro

# %% [markdown]
# ## Usage

# %% [markdown]
# With this notebook, real-time predictions can be made on signs you perform in front of your running webcam.
#
# ### <span style="color:green">Quick User Guide:
#
# <span style="color:green">1. Load your trained TF Model.</span>
#
# <span style="color:green">2. Copy + paste used Configurations from Franziska's pre-processing notebook</span>
#
# <span style="color:green">Optional: 3. Copy + paste used Pre-processing Layer from Franziska's pre-processing notebook</span>

# %% [markdown]
# ## Install and Import Dependencies

# %% [markdown]
# ### Install Dependencies

# %%
# %pip install tensorflow-macos opencv-python mediapipe-silicon sklearn matplotlib
#!pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 opencv-python mediapipe sklearn matplotlib # original code line from tutorial (he had a windows system)
# Out:
# Requirement already satisfied: tensorflow-macos in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (2.12.0)
# Requirement already satisfied: opencv-python in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (4.7.0.72)
# Requirement already satisfied: mediapipe-silicon in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (0.9.1)
# Requirement already satisfied: sklearn in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (0.0.post4)
# Requirement already satisfied: matplotlib in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (0.4.8)
# Requirement already satisfied: libclang>=13.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (3.3.0)
# Requirement already satisfied: packaging in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (3.20.3)
# Requirement already satisfied: setuptools in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.54.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.12.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from mediapipe-silicon) (23.1.0)
# Requirement already satisfied: opencv-contrib-python in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from mediapipe-silicon) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos) (0.40.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow-macos) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow-macos) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (2.28.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-macos) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow-macos) (6.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-macos) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-macos) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import Dependencies

# %%
# general
import numpy as np
import pandas as pd
import os # easier file path handling

# for camera feed
import cv2 # opencv
from matplotlib import pyplot as plt # imshow for easy visualization
import time # to insert "sleep" in between frames
import mediapipe as mp # for accessing and reading from webcam

# for model re-building
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# for loading .json dictionary
import json

# %% [markdown]
# ## <span style="color:green">Load Files</span>

# %% [markdown]
# ### <span style="color:green">Load Saved Model</span>
#
# #### <span style="color:green">Here, you can load your trained TensorFlow model, e.g. LSTM.</span>

# %%
# load model
model = tf.keras.models.load_model('../models/LSTM_model_20signs_7.h5')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %% [markdown]
# ### Load sign_to_prediction_index_map.json file

# %%
# label map dictionary 
#LABEL_MAP = json.load(open("../data/asl-signs/sign_to_prediction_index_map.json", "r")) 
LABEL_MAP = {'brown': 0,  'callonphone': 1,  'cow': 2,  'cry': 3,  'dad': 4,  'fireman': 5,  'frog': 6,  'gum': 7,  'icecream': 8,  'minemy': 9,  'nose': 10,  'owl': 11,  'please': 12,  'radio': 13,  'shhh': 14,  'shirt': 15,  'tomorrow': 16,  'uncle': 17,  'water': 18,  'who': 19}

# %%
list(LABEL_MAP.keys())
# Out:
# ['brown',
#  'callonphone',
#  'cow',
#  'cry',
#  'dad',
#  'fireman',
#  'frog',
#  'gum',
#  'icecream',
#  'minemy',
#  'nose',
#  'owl',
#  'please',
#  'radio',
#  'shhh',
#  'shirt',
#  'tomorrow',
#  'uncle',
#  'water',
#  'who']

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Game Mechanics

# %%
COUNTDOWN = 0
#SELECTED_SIGNS = ['hello', 'mom', 'dad', 'hungry', 'thirsty']
#SELECTED_SIGNS = ['apple', 'bath', 'owl', 'clown', 'better']
SELECTED_SIGNS = list(LABEL_MAP.keys())

# %% [markdown]
# ### <span style="color:green">Franziskas's Configuration :) </span>

# %% [markdown]
# #### <span style="color:green">For now, just copy + paste the "Configuration" cell from Franziska's notebook "TF_Load-PreprocessData.ipynb" into the following cell :D </span>
#
# #### <span style="color:green">These configuration must be the same ones, which you used to preprocess the data to train the TensorFlow model, which you loaded above! </span>

# %%
#limit dataset for quick test
QUICK_TEST = True
QUICK_LIMIT = 500

#Define length of sequences for padding or cutting; 22 is the median length of all sequences
LENGTH = 22

#define min or max length of sequences; sequences too long/too short will be dropped
#max value of 92 was defined by calculating the interquartile range
MIN_LENGTH = 10
MAX_LENGTH = 92

#final data will be flattened, if false data will be 3 dimensional
FLATTEN = False

#define initialization of numpy array 
ARRAY = False #(True=Zeros, False=empty values)

#Define padding mode 
#1 = padding at start&end; 2 = padding at end; 3 = no padding, 4 = copy first/lastframe, 5 = copy last frame)
#Note: Mode 3 will give you an error due to different lengths, working on that
PADDING = 2
CONSTANT_VALUE = 0 #only required for mode 1 and 2; enter tf.constant(float('nan')) for NaN

#define if z coordinate will be dropped
DROP_Z = True

#mirror, flips x coordinate for data augmentation
MIRROR = True

#define if csv file should be filtered
CSV_FILTER  = False
#define how many participants for test set
TEST_COUNT = 5 #5 participants account for ca 23% of dataset
#generate test or train dataset (True = Train dataset; False = Test dataset)
#TRAIN = True #only works if CSV_FILTER is activated
TRAIN = True

#filter for specific signs
SIGN_FILTER = True
sign_list = [0,1,5,8]

#define filenames for x and y:
feature_data = 'X' #x data
feature_labels = 'y' #y data

#use for test dataset
#feature_data = 'X_test_h6' #x data
#feature_labels = 'y_test_h6' #y data


RANDOM_STATE = 42

#Defining Landmarks
#index ranges for each landmark type
#dont change these landmarks
FACE = list(range(0, 468))
LEFT_HAND = list(range(468, 489))
POSE = list(range(489, 522))
POSE_UPPER = list(range(489, 510))
RIGHT_HAND = list(range(522, 543))
LIPS = [61, 185, 40, 39, 37,  0, 267, 269, 270, 409,
                 291,146, 91,181, 84, 17, 314, 405, 321, 375, 
                 78, 191, 80, 81, 82, 13, 312, 311, 310, 415, 
                 95, 88, 178, 87, 14,317, 402, 318, 324, 308]
lipsUpperOuter= [61, 185, 40, 39, 37, 0, 267, 269, 270, 409, 291]
lipsLowerOuter= [146, 91, 181, 84, 17, 314, 405, 321, 375, 291]
lipsUpperInner= [78, 191, 80, 81, 82, 13, 312, 311, 310, 415, 308]
lipsLowerInner= [78, 95, 88, 178, 87, 14, 317, 402, 318, 324, 308]
#defining landmarks that will be merged
averaging_sets = []

#generating list with all landmarks selected for preprocessing
#change landmarks you want to use here:
point_landmarks_right = RIGHT_HAND + lipsUpperInner + lipsLowerInner
point_landmarks_left = LEFT_HAND + lipsUpperInner + lipsLowerInner

#calculating sum of total landmarks used
LANDMARKS = len(point_landmarks_right) + len(averaging_sets)
print(f'Total count of used landmarks: {LANDMARKS}')

#defining input shape for model
if DROP_Z:
    INPUT_SHAPE = (LENGTH,LANDMARKS*2)
else:
    INPUT_SHAPE = (LENGTH,LANDMARKS*3)
print(INPUT_SHAPE)
# Out:
# Total count of used landmarks: 43
# (22, 86)

# %%
print(f'Total count of used landmarks: {LANDMARKS}')
print(INPUT_SHAPE)
# Out:
# Total count of used landmarks: 43
# (22, 86)

# %% [markdown]
# ### Visualization

# %%
TRANSITION_FRAMES = 10

# %% [markdown]
# ### Objects and Functions for MP Holistic Keypoints

# %% [markdown]
# #### Initialize MP Holistic Model

# %%
mp_holistic = mp.solutions.holistic # holistic model
mp_drawing = mp.solutions.drawing_utils # drawing utilities

# %% [markdown]
# #### Define Functions (later they all go into a python module for multiple use)

# %% [markdown]
# ##### mediapipe_detection()

# %%
# function to detect MP Holistic landmarks from an image, e.g. frames of your camera feed
def mediapipe_detection(image, model): 
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # color conversion BGR to RGB
    image.flags.writeable = False                   # image no longer writeable
    results = model.process(image)                  # make prediction
    image.flags.writeable = True                    # image is writeable again
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)  # color conversion back to original
    return image, results

# %% [markdown]
# ##### draw_styled_landmarks()

# %%
# function to draw landmarks points and connecting lines on top of an image, e.g. on top of your camera feed
def draw_styled_landmarks(image, results): 
    # draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                              mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                              mp_drawing.DrawingSpec(color=(224,208,64), thickness=1, circle_radius=1))
    # draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                              mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                              mp_drawing.DrawingSpec(color=(224,208,64), thickness=2, circle_radius=2)) 
    # draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                              mp_drawing.DrawingSpec(color=(224,208,64), thickness=2, circle_radius=4), 
                              mp_drawing.DrawingSpec(color=(235,206,135), thickness=2, circle_radius=2)) 
    # draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                              mp_drawing.DrawingSpec(color=(224,208,64), thickness=2, circle_radius=4), 
                              mp_drawing.DrawingSpec(color=(128,128,240), thickness=2, circle_radius=2))

# %% [markdown]
# ##### extract_keypoints()

# %%
# function to extract coordinates (+visibility) of all landmarks --> keypoints
# and concatenates everything into a flattened list 
def extract_keypoints(results): 
    face = np.array([[r.x, r.y, r.z] for r in results.face_landmarks.landmark]) if results.face_landmarks else np.zeros([468, 3])
    left_hand = np.array([[r.x, r.y, r.z] for r in results.left_hand_landmarks.landmark]) if results.left_hand_landmarks else np.zeros([21, 3])
    pose = np.array([[r.x, r.y, r.z] for r in results.pose_landmarks.landmark]) if results.pose_landmarks else np.zeros([33, 3]) # x, y, z and extra value visibility
    right_hand = np.array([[r.x, r.y, r.z] for r in results.right_hand_landmarks.landmark]) if results.right_hand_landmarks else np.zeros([21, 3])
    return np.concatenate([face, left_hand, pose, right_hand]) # original code
    # a flattened list with list of all face, left_hand, pose, right_hand landmark x, y, z, (+visibility) coordinates

# %% [markdown]
# ##### prob_viz()

# %%
# function to visualize predicted word probabilities with a dynamic real-time bar chart
def prob_viz(pred, image, SELECTED_SIGNS): 
    output_frame = image.copy() 
    bar_zero = 15
    
    for num, prob in enumerate(pred): 
        cv2.rectangle(output_frame, 
                      pt1=(bar_zero, 75+num*30), 
                      pt2=(bar_zero+int(prob*100), 95+num*30), 
                      color=(200, 200, 200), thickness=-1)
        # cv2.rectangle(image, start_point, end_point, color, thickness)
        cv2.putText(img=output_frame, 
                    text=SELECTED_SIGNS[num], 
                    org=(bar_zero, 95+num*30), 
                    fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=0.75, 
                    color=(50, 50, 50), 
                    thickness=1, lineType=cv2.LINE_AA)
        # cv2.putText(image, 'OpenCV', org, font, fontScale, color, thickness, cv2.LINE_AA)
    return output_frame

# %% [markdown]
# ## <span style="color:green">Pre-processing Layer</span>

# %% [markdown]
# ### Helper Function

# %%
def tf_nan_mean(x, axis=0):
    #calculates the mean of a TensorFlow tensor x along a specified axis while ignoring any NaN values in the tensor.
    return tf.reduce_sum(tf.where(tf.math.is_nan(x), tf.zeros_like(x), x), axis=axis) / tf.reduce_sum(tf.where(tf.math.is_nan(x), tf.zeros_like(x), tf.ones_like(x)), axis=axis)

# %%
def right_hand_percentage(x):
    #calculates percentage of right hand usage
    right = tf.gather(x, RIGHT_HAND, axis=1)
    left = tf.gather(x, LEFT_HAND, axis=1)
    right_count = tf.reduce_sum(tf.where(tf.math.is_nan(right), tf.zeros_like(right), tf.ones_like(right)))
    left_count = tf.reduce_sum(tf.where(tf.math.is_nan(left), tf.zeros_like(left), tf.ones_like(left)))
    return right_count / (left_count+right_count)

# %% [markdown]
# ### <span style="color:green">In the following cell copy + paste the pre-processing layer from Franziska's notebook (,if you added / changed something)</span>

# %%
#generating preprocessing layer that will be added to final model
class FeatureGen(tf.keras.layers.Layer):
    #defines custom tensorflow layer 
    def __init__(self):
        #initializes layer
        super(FeatureGen, self).__init__()
    
    def call(self, x_in, MIRROR=False):
        #drop z coordinates if required
        if DROP_Z:
            x_in = x_in[:, :, 0:2]
        if MIRROR:
            #flipping x coordinates
            x_in = np.array(x_in)
            x_in[:, :, 0] = (x_in[:, :, 0]-1)*(-1)
            x_in = tf.convert_to_tensor(x_in)

        #generates list with mean values for landmarks that will be merged
        x_list = [tf.expand_dims(tf_nan_mean(x_in[:, av_set[0]:av_set[0]+av_set[1], :], axis=1), axis=1) for av_set in averaging_sets]
        
        #extracts specific columns from input x_in defined by landmarks
        handedness = right_hand_percentage(x_in)
        if handedness > 0.5:
            x_list.append(tf.gather(x_in, point_landmarks_right, axis=1))
        else: 
            x_list.append(tf.gather(x_in, point_landmarks_left, axis=1))

        #concatenates the two tensors from above along axis 1/columns
        x = tf.concat(x_list, 1)

        #padding to desired length of sequence (defined by LENGTH)
        #get current number of rows
        x_padded = x
        current_rows = tf.shape(x_padded)[0]
        #if current number of rows is greater than desired number of rows, truncate excess rows
        if current_rows > LENGTH:
            x_padded = x_padded[:LENGTH, :, :]

        #if current number of rows is less than desired number of rows, add padding
        elif current_rows < LENGTH:
            #calculate amount of padding needed
            pad_rows = LENGTH - current_rows

            if PADDING ==4: #copy first/last frame
                if pad_rows %2 == 0: #if pad_rows is even
                    padding_front = tf.repeat(x_padded[0:1, :], pad_rows//2, axis=0)
                    padding_back = tf.repeat(x_padded[-1:, :], pad_rows//2, axis=0)
                else: #if pad_rows is odd
                    padding_front = tf.repeat(x_padded[0:1, :], (pad_rows//2)+1, axis=0)
                    padding_back = tf.repeat(x_padded[-1:, :], pad_rows//2, axis=0)
                x_padded = tf.concat([padding_front, x_padded, padding_back], axis=0)
            elif PADDING == 5: #copy last frame
                padding_back = tf.repeat(x_padded[-1:, :], pad_rows, axis=0)
                x_padded = tf.concat([x_padded, padding_back], axis=0)
            else:
                if PADDING ==1: #padding at start and end
                    if pad_rows %2 == 0: #if pad_rows is even
                        paddings = [[pad_rows//2, pad_rows//2], [0, 0], [0, 0]]
                    else: #if pad_rows is odd
                        paddings = [[pad_rows//2+1, pad_rows//2], [0, 0], [0, 0]]
                elif PADDING ==2: #padding only at the end of sequence
                    paddings = [[0, pad_rows], [0, 0], [0, 0]]
                elif PADDING ==3: #no padding
                    paddings = [[0, 0], [0, 0], [0, 0]]
                x_padded = tf.pad(x_padded, paddings, mode='CONSTANT', constant_values=CONSTANT_VALUE)

        x = x_padded
        current_rows = tf.shape(x)[0]

        #interpolate single missing values
        x = pd.DataFrame(np.array(x).flatten()).interpolate(method='linear', limit=2, limit_direction='both')
        #fill missing values with zeros
        x = tf.where(tf.math.is_nan(x), tf.zeros_like(x), x)
        
        #reshape data to 2D or 3D array
        if FLATTEN:
            x = tf.reshape(x, (1, current_rows*INPUT_SHAPE[1]))
        else:
            x = tf.reshape(x, (1, current_rows, INPUT_SHAPE[1]))

        return x

#define converter using generated layer
feature_converter = FeatureGen()

# %% [markdown]
# ## Real Time Prediction / Detection

# %% [markdown]
# Press "Q" to interrupt the camera feed.

# %%
# 1. New detection variables 
sequence = [] # to collect all 22 frames for prediction
sentence = [] # history of all predictions (predicted words)
predictions = []
threshold = 0.7 # confidence metrics (only render prediction results, if confidence is above threshold)

cap = cv2.VideoCapture(0) # grabbing webcam

# set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic: 
    while cap.isOpened(): # loop through all frames 

        # read feed
        ret, frame = cap.read()
        #frame = cv2.flip(frame, 0) # maybe we need to flip the image? 

        # make detections 
        image, results = mediapipe_detection(frame, holistic)
        #print(results)

        #draw_landmarks(image, results)
        draw_styled_landmarks(image, results)

        # 2. Prediction logic
        keypoints = extract_keypoints(results) # extract keypoints x, y, z for face, left_hand, pose, right_hand from mediapipe holistic predictions, keypoints.shape e.g. (543, 3)
        sequence.append(keypoints) # keep appending keypoints (frames) to a sequence, np.array(sequence).shape e.g. (22, 543, 3)
        sequence = sequence[-LENGTH:] # takes last LENGTH frames of the sequence

        # 
        if len(sequence) == LENGTH: 
            # pre-processing
            model_input = feature_converter(np.array(sequence))
            #print(f'OMG! Frenzy Franzi is converting your mediapipe input! See how the shape is changing from {np.array(sequence).shape} to {model_input.shape}! SO AWESOME!!!')
            
            # prediction
            pred = model.predict(model_input)[0] # model.fit() expects something in shape (num_sequences, 30, 1662), e.g. (1, 30, 1662) for a single sequence
            selected_labels = [LABEL_MAP[x] for x in SELECTED_SIGNS]
            pred_all = pred 
            pred = pred[selected_labels]
            predictions.append(np.argmax(pred))

            # 3. Visualization logic
            # makes sure the last x frames had the same prediction (more stable transition from one sign to another) 
            if np.unique(predictions[-TRANSITION_FRAMES:])[0]==np.argmax(pred): 
                # if the confidence of the most confident prediction is above threshold
                if pred[np.argmax(pred)] > threshold: 
                    # if there is already a last prediction
                    if len(sentence) > 0: 
                        # only append the predicted word, if it differs from the last prediction (prevent double actions)
                        if SELECTED_SIGNS[np.argmax(pred)] != sentence[-1]: 
                            sentence.append(SELECTED_SIGNS[np.argmax(pred)])
                    # just append if there is no last prediction (first prediction)
                    else: 
                        sentence.append(SELECTED_SIGNS[np.argmax(pred)])

            # limit the history to the last 5 predictions
            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # viz probabilities
            print(f'Example prediction for "{SELECTED_SIGNS[np.argmax(pred)]}": {pred[np.argmax(pred)]}')
            image = prob_viz(pred, image, SELECTED_SIGNS)

        # some rendering
        cv2.rectangle(image, (0, 0), (1280, 60), (200, 200, 200), -1)
        cv2.putText(image, ' '.join(sentence), (45, 45), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (52, 75, 102), 1, cv2.LINE_AA)
        # cv2.putText(image, 'OpenCV', org, font, fontScale, color, thickness, cv2.LINE_AA)

        # show to screen
        cv2.imshow("OpenCV Feed", image)

        # break gracefully 
        if cv2.waitKey(10) & 0xFF == ord('q'): 
            break 
        
# release camera and close feed window 
cap.release()
cv2.destroyAllWindows() 
cv2.waitKey(1) # some workaround to fix the bug, that window doesn't close
# Out:
# 1/1 [==============================] - 0s 282ms/step
# Example prediction for "please": 0.9173188805580139
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9173685312271118
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9236218333244324
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.928912341594696
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9329107999801636
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9355195164680481
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9417533874511719
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9448115825653076
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9431125521659851
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9394461512565613
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9327864050865173
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9227227568626404
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9096331000328064
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8928572535514832
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8708294034004211
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8466076254844666
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.8226051330566406
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.8111007809638977
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "nose": 0.966881275177002
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "who": 0.9999501705169678
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "who": 0.37327149510383606
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "water": 0.5932844877243042
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "water": 0.7852420210838318
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "water": 0.8192675113677979
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "water": 0.826187014579773
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "gum": 0.738991379737854
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "dad": 0.9193552136421204
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "gum": 0.7847278118133545
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "nose": 0.7149870991706848
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "radio": 0.9999256134033203
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "radio": 0.9999872446060181
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "radio": 0.9999243021011353
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "radio": 0.999356210231781
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "radio": 0.9962272644042969
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "radio": 0.9908221960067749
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "radio": 0.9901911020278931
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "radio": 0.9931381344795227
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "radio": 0.9871644973754883
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "radio": 0.6082317233085632
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "uncle": 0.984618067741394
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "brown": 0.515311598777771
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.8902300000190735
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.9756609797477722
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "fireman": 0.6491255760192871
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "fireman": 0.998104453086853
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "fireman": 0.9993174076080322
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "fireman": 0.9938417673110962
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "fireman": 0.986498236656189
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "fireman": 0.5066128969192505
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "fireman": 0.8523415923118591
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "fireman": 0.8251528739929199
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "fireman": 0.5987387895584106
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "fireman": 0.7353028059005737
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "fireman": 0.9315974116325378
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "fireman": 0.9832062125205994
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "fireman": 0.9991424083709717
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "fireman": 0.9973904490470886
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "fireman": 0.9914804697036743
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "fireman": 0.695202112197876
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 0.9986227750778198
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 0.9999771118164062
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 0.9999842643737793
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 0.9996771812438965
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 0.8495901226997375
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "please": 0.9912761449813843
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9999743700027466
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.8631308078765869
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.3643788993358612
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.6357948184013367
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.8365798592567444
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7864668965339661
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.7435750365257263
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7206671833992004
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6995071172714233
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6673319339752197
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6211491823196411
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5587449073791504
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.48602911829948425
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.42136675119400024
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.36664554476737976
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.3438296914100647
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.3544536530971527
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.39282211661338806
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.4377683401107788
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.4682689905166626
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.4537089169025421
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.41060373187065125
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.3472867012023926
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.3546353280544281
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.3437286913394928
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.33253300189971924
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.3208216726779938
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.30890583992004395
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.3053435683250427
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.35744988918304443
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.42062169313430786
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.481768399477005
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5178576111793518
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5315955281257629
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5134727358818054
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.47657790780067444
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.44453370571136475
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.41967418789863586
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.3948446810245514
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.3806140720844269
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.36642351746559143
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.33679288625717163
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.32378432154655457
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.34710901975631714
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.40636613965034485
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.4876493215560913
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5388733744621277
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5592427253723145
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5551812052726746
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.535163164138794
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.4875858426094055
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.42545363306999207
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.42268106341362
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.448942631483078
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.49625885486602783
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5466590523719788
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.605034589767456
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.671393632888794
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7284775972366333
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.763759195804596
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7950530648231506
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8041502237319946
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7952818274497986
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7839943766593933
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.7631744146347046
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.7664279937744141
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7741261720657349
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7854728102684021
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7968103289604187
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.804765522480011
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8166338205337524
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.833676278591156
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8686070442199707
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8982738852500916
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9169225692749023
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9277603626251221
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9379199743270874
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9465766549110413
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9492220282554626
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9486390948295593
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9420280456542969
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9334418773651123
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9285407662391663
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9241814017295837
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9168146848678589
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9002687335014343
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8750157356262207
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8622786402702332
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8490267992019653
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.8408158421516418
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8522243499755859
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.8716194033622742
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8834026455879211
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8898595571517944
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8947218656539917
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8878650069236755
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.874406635761261
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8752914071083069
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8780452609062195
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8724489212036133
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8661043047904968
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8660340905189514
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.859578549861908
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8487692475318909
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8476137518882751
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8472490906715393
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8425033688545227
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.840772807598114
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.839300274848938
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8302461504936218
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8335449695587158
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8432310819625854
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8562737107276917
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8849027156829834
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9105700254440308
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9268403649330139
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.935982346534729
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.937134325504303
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9281664490699768
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9141848087310791
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.911181628704071
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9163692593574524
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9213151931762695
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9277718663215637
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.934074342250824
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9384814500808716
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9449910521507263
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9531021118164062
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9584367871284485
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9615545868873596
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9621602892875671
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9577862620353699
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9535914063453674
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9504882097244263
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9421708583831787
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9342356324195862
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9234308004379272
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8995188474655151
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8701821565628052
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.8580648303031921
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8508172631263733
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8414077162742615
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.835713267326355
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8384996652603149
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.845824122428894
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8551308512687683
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.873336911201477
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8823251128196716
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8948158025741577
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9073572754859924
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9204664826393127
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.934114933013916
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9448779225349426
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9453048706054688
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9469343423843384
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9490514397621155
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.948401153087616
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9444431066513062
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9374497532844543
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.927705705165863
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9115320444107056
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8798524141311646
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8324243426322937
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7837736010551453
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.748082160949707
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.7356719970703125
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7448853850364685
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7481644749641418
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7327466607093811
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7076873183250427
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6841802000999451
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6921746134757996
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.6733421683311462
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.6221334338188171
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.5509462952613831
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.4621935784816742
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.3815442621707916
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.34282150864601135
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "owl": 0.36022281646728516
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.36992573738098145
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.3774409294128418
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "owl": 0.3822396397590637
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "owl": 0.38640832901000977
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "owl": 0.3936130106449127
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "owl": 0.3939940631389618
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.3884895145893097
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.37542733550071716
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.3553398847579956
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.3383762538433075
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.3234786093235016
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "owl": 0.30259981751441956
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.3040219843387604
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.3519296646118164
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.4000130891799927
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.45080745220184326
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.4878986179828644
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5134866237640381
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5345260500907898
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.560772180557251
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5955936908721924
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6248261332511902
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6725897789001465
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7423759698867798
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7959257960319519
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8273923993110657
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8447974324226379
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8505021929740906
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8507228493690491
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8460217714309692
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8450047373771667
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8521392345428467
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8527951240539551
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8467307090759277
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8584051132202148
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8572138547897339
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8474491238594055
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.841962993144989
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8385728597640991
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8324251770973206
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8332375884056091
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8439589738845825
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8595814108848572
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.8780651688575745
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8885725140571594
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.894598126411438
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9076955318450928
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9168329238891602
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9191091656684875
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9198707938194275
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9133791923522949
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9051740169525146
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9020581841468811
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8990064859390259
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.8896260857582092
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8782851696014404
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8694357872009277
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.8521441221237183
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.8357771039009094
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8241046071052551
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8027387857437134
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7766452431678772
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7609433531761169
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7414281964302063
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.7187286615371704
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7064454555511475
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6929951310157776
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.668476402759552
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6533958911895752
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6434316039085388
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6260955333709717
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6100696921348572
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6120554804801941
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5882379412651062
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.545087993144989
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5091506838798523
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.48796939849853516
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.48286306858062744
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.4857855439186096
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.4877321124076843
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.4983479976654053
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.515561044216156
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5280715227127075
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5394306778907776
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5568662881851196
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5804674625396729
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6074801087379456
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.6305789947509766
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6400083899497986
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6522929668426514
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6631548404693604
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.6698179244995117
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.6758363842964172
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.6911712288856506
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.7002646923065186
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7095810174942017
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.7240800857543945
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.717557966709137
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.6917056441307068
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6817166805267334
# 1/1 [==============================] - 0s 21ms/step
# Example prediction for "please": 0.6780148148536682
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.6728885769844055
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.6738913655281067
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6630933880805969
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.6539857387542725
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6241780519485474
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5892648100852966
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.5429369211196899
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.4828529357910156
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.4409647285938263
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.4197577238082886
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.39896395802497864
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.38918060064315796
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.38513463735580444
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.3816307783126831
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.36342141032218933
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.34606486558914185
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.31841668486595154
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.3113652765750885
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "owl": 0.3109988570213318
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "owl": 0.3141355514526367
# 1/1 [==============================] - 0s 18ms/step
# Example prediction for "owl": 0.325198769569397
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.3380521237850189
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.3543637692928314
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "owl": 0.3632117509841919
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.36742812395095825
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "owl": 0.3643836975097656
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "owl": 0.3613993525505066
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "owl": 0.36366215348243713
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "owl": 0.3684682846069336
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "owl": 0.36053070425987244
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.34864065051078796
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "cow": 0.36317309737205505
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "cow": 0.3896632492542267
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "cow": 0.4071609377861023
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "cow": 0.39825358986854553
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "cow": 0.3813351094722748
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "owl": 0.3769437074661255
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.3813498318195343
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.3817930221557617
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "owl": 0.38359540700912476
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "owl": 0.3894376754760742
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "owl": 0.39227914810180664
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.3919546902179718
# 1/1 [==============================] - 0s 19ms/step
# Example prediction for "owl": 0.3850450813770294
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "owl": 0.37779784202575684
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.37083956599235535
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "owl": 0.3639395833015442
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "owl": 0.3572293519973755
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.3489142060279846
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.34285426139831543
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.3366791605949402
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.32980796694755554
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.323401540517807
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "owl": 0.31786713004112244
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.32959333062171936
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.3445225656032562
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.35353532433509827
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.3543033003807068
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.3520309627056122
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.3476253151893616
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.34218353033065796
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.34660837054252625
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.3577130138874054
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.36842626333236694
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.3820881247520447
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.3949718475341797
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.4067310690879822
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.4154540002346039
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.42023202776908875
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.4233524203300476
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.4207915663719177
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.4172095060348511
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.4190795421600342
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.4214179217815399
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.4251355826854706
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.4234602153301239
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.40942904353141785
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.3798203766345978
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.3455340266227722
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.3256978690624237
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "owl": 0.32905876636505127
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.33368751406669617
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "owl": 0.3377048969268799
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.3543056845664978
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.38082993030548096
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.44358840584754944
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.5326040387153625
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.6296312212944031
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.7135848999023438
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.7718225121498108
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.7646446824073792
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.7585598826408386
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.7525207996368408
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.7527545094490051
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.7577528357505798
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.7421033382415771
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.7553967833518982
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.7552404999732971
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.789717972278595
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.8296698927879333
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.860299289226532
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.8758335113525391
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9631182551383972
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.986184298992157
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9902780652046204
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "nose": 0.7071555256843567
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "who": 0.9999996423721313
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "who": 0.9999779462814331
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "who": 0.9869638085365295
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "minemy": 0.9985836744308472
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "minemy": 0.9903539419174194
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "minemy": 0.8910282850265503
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "minemy": 0.7763763070106506
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "minemy": 0.527343213558197
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.8391908407211304
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9150469899177551
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.919996976852417
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.8611690998077393
# ...
# Example prediction for "please": 0.7640612125396729
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.795781135559082
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.8158403038978577
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.8310962915420532
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.8413851857185364
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.8447558283805847
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.8451958894729614
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "please": 0.839643120765686
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "please": 0.8431910276412964
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.8590014576911926
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.8824662566184998
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9101793766021729
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9343374967575073
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9549470543861389
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9651614427566528
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.9661792516708374
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9620299935340881
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9543501734733582
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9445957541465759
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9358696937561035
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9319594502449036
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9303833842277527
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "please": 0.9293883442878723
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9295163154602051
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.930794358253479
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9332959055900574
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.936590850353241
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9438683390617371
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9558400511741638
# 1/1 [==============================] - 0s 20ms/step
# Example prediction for "please": 0.9645928740501404
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.9698953032493591
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9712226986885071
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9704117774963379
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9683150053024292
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9656153917312622
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.9620612263679504
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9581760168075562
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9550567269325256
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "please": 0.9528951048851013
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.951156735420227
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.9491742849349976
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.9479667544364929
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9489635229110718
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9516809582710266
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9550477266311646
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9578469395637512
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9599051475524902
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9606338143348694
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9613510370254517
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "please": 0.9623070955276489
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9632858037948608
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9614118933677673
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9577910304069519
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9525179862976074
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.9459799528121948
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9398118257522583
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9350780844688416
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9313198924064636
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9283871054649353
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9284152984619141
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9303324818611145
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.93229740858078
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9353349804878235
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9416031837463379
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9481791257858276
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.9548936486244202
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9607920050621033
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9645669460296631
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.9643549919128418
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9607203006744385
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9560918211936951
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9512556791305542
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9473459124565125
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9463692903518677
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9466913938522339
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "please": 0.947777271270752
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.949282705783844
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9508684277534485
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9527401924133301
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9537987112998962
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9543441534042358
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9550576210021973
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9557976722717285
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9566323757171631
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "please": 0.957569420337677
# 1/1 [==============================] - 0s 45ms/step
# Example prediction for "please": 0.9582934975624084
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9588613510131836
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9593179225921631
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9596444368362427
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9599609375
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9595608115196228
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9597303867340088
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.960294783115387
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9607850909233093
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9611718654632568
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9616093635559082
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9619134664535522
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9620897769927979
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9622291922569275
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9625387787818909
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "please": 0.9633072018623352
# 1/1 [==============================] - 0s 19ms/step
# Example prediction for "please": 0.9634387493133545
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9633572697639465
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.963038980960846
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9607303142547607
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9584208130836487
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.955845057964325
# 1/1 [==============================] - 0s 19ms/step
# Example prediction for "please": 0.9526464939117432
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.9484379291534424
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9444212317466736
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9416031837463379
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9407536387443542
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9428325295448303
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9450159668922424
# 1/1 [==============================] - 0s 19ms/step
# Example prediction for "please": 0.9469087719917297
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.9484735131263733
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9487611055374146
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9465480446815491
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9420520663261414
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9340363144874573
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9231010675430298
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9162951707839966
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.91383957862854
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "please": 0.9135554432868958
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9145112037658691
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9160923361778259
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9180592894554138
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9202228784561157
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9222418069839478
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9235426187515259
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.9250266551971436
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9257388710975647
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.925577700138092
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.92534339427948
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.924881637096405
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9246038198471069
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9248842000961304
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9253814816474915
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9258965849876404
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "please": 0.9268211126327515
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9275039434432983
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9289368391036987
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9300000667572021
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9309989809989929
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9319274425506592
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9323307871818542
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "please": 0.9330365657806396
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "please": 0.9328467845916748
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9312666654586792
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "please": 0.9308004379272461
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.9282240867614746
# -1
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model_input[0,0,:]

# %%
np.max(model_input)
# Out:
# 0.61182153

# %% [markdown]
# ## Next steps
#
# Save the recordings and predictions for later use?
#
# Add a feature, so that the user can type into a textbox to correct wrong prediction + real-time training / update of the model?
