# %% [markdown]
# # Real-Time Prediction

# %% [markdown]
# ## Reference

# %% [markdown]
# The code in this notebook is adapted and modified from the following Youtube tutorial: https://www.youtube.com/watch?v=doDUihpj6ro

# %% [markdown]
# ## Usage

# %% [markdown]
# With this notebook, real-time predictions can be made on signs you perform in front of your running webcam.
#
# ### <span style="color:green">Quick User Guide:
#
# <span style="color:green">1. Load your trained TF Model.</span>
#
# <span style="color:green">2. Copy + paste used Configurations from Franziska's pre-processing notebook</span>
#
# <span style="color:green">Optional: 3. Copy + paste used Pre-processing Layer from Franziska's pre-processing notebook</span>

# %% [markdown]
# ## Install and Import Dependencies

# %% [markdown]
# ### Install Dependencies

# %%
# %pip install tensorflow-macos opencv-python mediapipe-silicon sklearn matplotlib
#!pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 opencv-python mediapipe sklearn matplotlib # original code line from tutorial (he had a windows system)
# Out:
# Requirement already satisfied: tensorflow-macos in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (2.12.0)
# Requirement already satisfied: opencv-python in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (4.7.0.72)
# Requirement already satisfied: mediapipe-silicon in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (0.9.1)
# Requirement already satisfied: sklearn in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (0.0.post4)
# Requirement already satisfied: matplotlib in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (0.4.8)
# Requirement already satisfied: libclang>=13.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (3.3.0)
# Requirement already satisfied: packaging in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (3.20.3)
# Requirement already satisfied: setuptools in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.54.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.12.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from mediapipe-silicon) (23.1.0)
# Requirement already satisfied: opencv-contrib-python in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from mediapipe-silicon) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos) (0.40.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow-macos) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow-macos) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (2.28.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-macos) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow-macos) (6.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-macos) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-macos) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import Dependencies

# %%
# general
import numpy as np
import pandas as pd
import os # easier file path handling

# for camera feed
import cv2 # opencv
from matplotlib import pyplot as plt # imshow for easy visualization
import time # to insert "sleep" in between frames
import mediapipe as mp # for accessing and reading from webcam

# for model re-building
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# for loading .json dictionary
import json

# %% [markdown]
# ## <span style="color:green">Load Files</span>

# %% [markdown]
# ### <span style="color:green">Load Saved Model</span>
#
# #### <span style="color:green">Here, you can load your trained TensorFlow model, e.g. LSTM.</span>

# %%
# load model
model = tf.keras.models.load_model('../models/LSTM_model_20signs_7.h5')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %% [markdown]
# ### Load sign_to_prediction_index_map.json file

# %%
# label map dictionary 
LABEL_MAP = json.load(open("../data/asl-signs/sign_to_prediction_index_map.json", "r")) 

# actions to detect
actions = np.array(list(LABEL_MAP.keys()))

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Game Mechanics

# %%
LABEL_MAP = {'brown': 0,  'callonphone': 1,  'cow': 2,  'cry': 3,  'dad': 4,  'fireman': 5,  'frog': 6,  'gum': 7,  'icecream': 8,  'minemy': 9,  'nose': 10,  'owl': 11,  'please': 12,  'radio': 13,  'shhh': 14,  'shirt': 15,  'tomorrow': 16,  'uncle': 17,  'water': 18,  'who': 19}

# %%
COUNTDOWN = 0
#SELECTED_SIGNS = ['hello', 'mom', 'dad', 'hungry', 'thirsty']
#SELECTED_SIGNS = ['apple', 'bath', 'owl', 'clown', 'better']
SELECTED_SIGNS = ['shhh', 'water', 'cow', 'owl', 'nose']

# %% [markdown]
# ### <span style="color:green">Franziskas's Configuration :) </span>

# %% [markdown]
# #### <span style="color:green">For now, just copy + paste the "Configuration" cell from Franziska's notebook "TF_Load-PreprocessData.ipynb" into the following cell :D </span>
#
# #### <span style="color:green">These configuration must be the same ones, which you used to preprocess the data to train the TensorFlow model, which you loaded above! </span>

# %%
#limit dataset for quick test
QUICK_TEST = True
QUICK_LIMIT = 500

#Define length of sequences for padding or cutting; 22 is the median length of all sequences
LENGTH = 22

#define min or max length of sequences; sequences too long/too short will be dropped
#max value of 92 was defined by calculating the interquartile range
MIN_LENGTH = 10
MAX_LENGTH = 92

#final data will be flattened, if false data will be 3 dimensional
FLATTEN = False

#define initialization of numpy array 
ARRAY = False #(True=Zeros, False=empty values)

#Define padding mode 
#1 = padding at start&end; 2 = padding at end; 3 = no padding, 4 = copy first/lastframe, 5 = copy last frame)
#Note: Mode 3 will give you an error due to different lengths, working on that
PADDING = 2
CONSTANT_VALUE = 0 #only required for mode 1 and 2; enter tf.constant(float('nan')) for NaN

#define if z coordinate will be dropped
DROP_Z = True

#mirror, flips x coordinate for data augmentation
MIRROR = True

#define if csv file should be filtered
CSV_FILTER  = False
#define how many participants for test set
TEST_COUNT = 5 #5 participants account for ca 23% of dataset
#generate test or train dataset (True = Train dataset; False = Test dataset)
#TRAIN = True #only works if CSV_FILTER is activated
TRAIN = True

#filter for specific signs
SIGN_FILTER = True
sign_list = [0,1,5,8]

#define filenames for x and y:
feature_data = 'X' #x data
feature_labels = 'y' #y data

#use for test dataset
#feature_data = 'X_test_h6' #x data
#feature_labels = 'y_test_h6' #y data


RANDOM_STATE = 42

#Defining Landmarks
#index ranges for each landmark type
#dont change these landmarks
FACE = list(range(0, 468))
LEFT_HAND = list(range(468, 489))
POSE = list(range(489, 522))
POSE_UPPER = list(range(489, 510))
RIGHT_HAND = list(range(522, 543))
LIPS = [61, 185, 40, 39, 37,  0, 267, 269, 270, 409,
                 291,146, 91,181, 84, 17, 314, 405, 321, 375, 
                 78, 191, 80, 81, 82, 13, 312, 311, 310, 415, 
                 95, 88, 178, 87, 14,317, 402, 318, 324, 308]
lipsUpperOuter= [61, 185, 40, 39, 37, 0, 267, 269, 270, 409, 291]
lipsLowerOuter= [146, 91, 181, 84, 17, 314, 405, 321, 375, 291]
lipsUpperInner= [78, 191, 80, 81, 82, 13, 312, 311, 310, 415, 308]
lipsLowerInner= [78, 95, 88, 178, 87, 14, 317, 402, 318, 324, 308]
#defining landmarks that will be merged
averaging_sets = []

#generating list with all landmarks selected for preprocessing
#change landmarks you want to use here:
point_landmarks_right = RIGHT_HAND + lipsUpperInner + lipsLowerInner
point_landmarks_left = LEFT_HAND + lipsUpperInner + lipsLowerInner

#calculating sum of total landmarks used
LANDMARKS = len(point_landmarks_right) + len(averaging_sets)
print(f'Total count of used landmarks: {LANDMARKS}')

#defining input shape for model
if DROP_Z:
    INPUT_SHAPE = (LENGTH,LANDMARKS*2)
else:
    INPUT_SHAPE = (LENGTH,LANDMARKS*3)
print(INPUT_SHAPE)
# Out:
# Total count of used landmarks: 43
# (22, 86)

# %%
print(f'Total count of used landmarks: {LANDMARKS}')
print(INPUT_SHAPE)
# Out:
# Total count of used landmarks: 43
# (22, 86)

# %% [markdown]
# ### Visualization

# %%
TRANSITION_FRAMES = LENGTH

# %% [markdown]
# ### Objects and Functions for MP Holistic Keypoints

# %% [markdown]
# #### Initialize MP Holistic Model

# %%
mp_holistic = mp.solutions.holistic # holistic model
mp_drawing = mp.solutions.drawing_utils # drawing utilities

# %% [markdown]
# #### Define Functions (later they all go into a python module for multiple use)

# %% [markdown]
# ##### mediapipe_detection()

# %%
# function to detect MP Holistic landmarks from an image, e.g. frames of your camera feed
def mediapipe_detection(image, model): 
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # color conversion BGR to RGB
    image.flags.writeable = False                   # image no longer writeable
    results = model.process(image)                  # make prediction
    image.flags.writeable = True                    # image is writeable again
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)  # color conversion back to original
    return image, results

# %% [markdown]
# ##### draw_styled_landmarks()

# %%
# function to draw landmarks points and connecting lines on top of an image, e.g. on top of your camera feed
def draw_styled_landmarks(image, results): 
    # draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                              mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                              mp_drawing.DrawingSpec(color=(224,208,64), thickness=1, circle_radius=1))
    # draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                              mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                              mp_drawing.DrawingSpec(color=(224,208,64), thickness=2, circle_radius=2)) 
    # draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                              mp_drawing.DrawingSpec(color=(224,208,64), thickness=2, circle_radius=4), 
                              mp_drawing.DrawingSpec(color=(235,206,135), thickness=2, circle_radius=2)) 
    # draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                              mp_drawing.DrawingSpec(color=(224,208,64), thickness=2, circle_radius=4), 
                              mp_drawing.DrawingSpec(color=(128,128,240), thickness=2, circle_radius=2))

# %% [markdown]
# ##### extract_keypoints()

# %%
# function to extract coordinates (+visibility) of all landmarks --> keypoints
# and concatenates everything into a flattened list 
def extract_keypoints(results): 
    face = np.array([[r.x, r.y, r.z] for r in results.face_landmarks.landmark]) if results.face_landmarks else np.zeros([468, 3])
    left_hand = np.array([[r.x, r.y, r.z] for r in results.left_hand_landmarks.landmark]) if results.left_hand_landmarks else np.zeros([21, 3])
    pose = np.array([[r.x, r.y, r.z] for r in results.pose_landmarks.landmark]) if results.pose_landmarks else np.zeros([33, 3]) # x, y, z and extra value visibility
    right_hand = np.array([[r.x, r.y, r.z] for r in results.right_hand_landmarks.landmark]) if results.right_hand_landmarks else np.zeros([21, 3])
    return np.concatenate([face, pose, left_hand, right_hand]) # original code
    # a flattened list with list of all pose, face, left_hand, right_hand landmark x, y, z, (+visibility) coordinates

# %% [markdown]
# ##### prob_viz()

# %%
# function to visualize predicted word probabilities with a dynamic real-time bar chart
def prob_viz(pred, actions, input_frame): 
    output_frame = input_frame.copy() 
    bar_zero = 15
    
    for num, prob in enumerate(pred): 
        cv2.rectangle(output_frame, 
                      pt1=(bar_zero, 65+num*50), 
                      pt2=(bar_zero+int(prob*100*5), 95+num*50), 
                      color=(200, 200, 200), thickness=-1)
        # cv2.rectangle(image, start_point, end_point, color, thickness)
        cv2.putText(img=output_frame, 
                    text=SELECTED_SIGNS[num], 
                    org=(bar_zero, 90+num*50), 
                    fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=1, 
                    color=(50, 50, 50), 
                    thickness=1, lineType=cv2.LINE_AA)
        # cv2.putText(image, 'OpenCV', org, font, fontScale, color, thickness, cv2.LINE_AA)
    return output_frame

# %% [markdown]
# ## <span style="color:green">Pre-processing Layer</span>

# %% [markdown]
# ### Helper Function

# %%
def tf_nan_mean(x, axis=0):
    #calculates the mean of a TensorFlow tensor x along a specified axis while ignoring any NaN values in the tensor.
    return tf.reduce_sum(tf.where(tf.math.is_nan(x), tf.zeros_like(x), x), axis=axis) / tf.reduce_sum(tf.where(tf.math.is_nan(x), tf.zeros_like(x), tf.ones_like(x)), axis=axis)

# %%
def right_hand_percentage(x):
    #calculates percentage of right hand usage
    right = tf.gather(x, RIGHT_HAND, axis=1)
    left = tf.gather(x, LEFT_HAND, axis=1)
    right_count = tf.reduce_sum(tf.where(tf.math.is_nan(right), tf.zeros_like(right), tf.ones_like(right)))
    left_count = tf.reduce_sum(tf.where(tf.math.is_nan(left), tf.zeros_like(left), tf.ones_like(left)))
    return right_count / (left_count+right_count)

# %% [markdown]
# ### <span style="color:green">In the following cell copy + paste the pre-processing layer from Franziska's notebook (,if you added / changed something)</span>

# %%
#generating preprocessing layer that will be added to final model
class FeatureGen(tf.keras.layers.Layer):
    #defines custom tensorflow layer 
    def __init__(self):
        #initializes layer
        super(FeatureGen, self).__init__()
    
    def call(self, x_in, MIRROR=False):
        #drop z coordinates if required
        if DROP_Z:
            x_in = x_in[:, :, 0:2]
        if MIRROR:
            #flipping x coordinates
            x_in = np.array(x_in)
            x_in[:, :, 0] = (x_in[:, :, 0]-1)*(-1)
            x_in = tf.convert_to_tensor(x_in)

        #generates list with mean values for landmarks that will be merged
        x_list = [tf.expand_dims(tf_nan_mean(x_in[:, av_set[0]:av_set[0]+av_set[1], :], axis=1), axis=1) for av_set in averaging_sets]
        
        #extracts specific columns from input x_in defined by landmarks
        handedness = right_hand_percentage(x_in)
        if handedness > 0.5:
            x_list.append(tf.gather(x_in, point_landmarks_right, axis=1))
        else: 
            x_list.append(tf.gather(x_in, point_landmarks_left, axis=1))

        #concatenates the two tensors from above along axis 1/columns
        x = tf.concat(x_list, 1)

        #padding to desired length of sequence (defined by LENGTH)
        #get current number of rows
        x_padded = x
        current_rows = tf.shape(x_padded)[0]
        #if current number of rows is greater than desired number of rows, truncate excess rows
        if current_rows > LENGTH:
            x_padded = x_padded[:LENGTH, :, :]

        #if current number of rows is less than desired number of rows, add padding
        elif current_rows < LENGTH:
            #calculate amount of padding needed
            pad_rows = LENGTH - current_rows

            if PADDING ==4: #copy first/last frame
                if pad_rows %2 == 0: #if pad_rows is even
                    padding_front = tf.repeat(x_padded[0:1, :], pad_rows//2, axis=0)
                    padding_back = tf.repeat(x_padded[-1:, :], pad_rows//2, axis=0)
                else: #if pad_rows is odd
                    padding_front = tf.repeat(x_padded[0:1, :], (pad_rows//2)+1, axis=0)
                    padding_back = tf.repeat(x_padded[-1:, :], pad_rows//2, axis=0)
                x_padded = tf.concat([padding_front, x_padded, padding_back], axis=0)
            elif PADDING == 5: #copy last frame
                padding_back = tf.repeat(x_padded[-1:, :], pad_rows, axis=0)
                x_padded = tf.concat([x_padded, padding_back], axis=0)
            else:
                if PADDING ==1: #padding at start and end
                    if pad_rows %2 == 0: #if pad_rows is even
                        paddings = [[pad_rows//2, pad_rows//2], [0, 0], [0, 0]]
                    else: #if pad_rows is odd
                        paddings = [[pad_rows//2+1, pad_rows//2], [0, 0], [0, 0]]
                elif PADDING ==2: #padding only at the end of sequence
                    paddings = [[0, pad_rows], [0, 0], [0, 0]]
                elif PADDING ==3: #no padding
                    paddings = [[0, 0], [0, 0], [0, 0]]
                x_padded = tf.pad(x_padded, paddings, mode='CONSTANT', constant_values=CONSTANT_VALUE)

        x = x_padded
        current_rows = tf.shape(x)[0]

        #interpolate single missing values
        x = pd.DataFrame(np.array(x).flatten()).interpolate(method='linear', limit=2, limit_direction='both')
        #fill missing values with zeros
        x = tf.where(tf.math.is_nan(x), tf.zeros_like(x), x)
        
        #reshape data to 2D or 3D array
        if FLATTEN:
            x = tf.reshape(x, (1, current_rows*INPUT_SHAPE[1]))
        else:
            x = tf.reshape(x, (1, current_rows, INPUT_SHAPE[1]))

        return x

#define converter using generated layer
feature_converter = FeatureGen()

# %% [markdown]
# ## Real Time Prediction / Detection

# %% [markdown]
# Press "Q" to interrupt the camera feed.

# %%
keypoints[:,0].min()
keypoints[:,2].min()
# Out:
# -1.2856690883636475

# %%
# 1. New detection variables 
sequence = [] # to collect all 22 frames for prediction
sentence = [] # history of all predictions (predicted words)
predictions = []
threshold = 0.2 # confidence metrics (only render prediction results, if confidence is above threshold)

cap = cv2.VideoCapture(0) # grabbing webcam
# set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic: 
    while cap.isOpened(): # loop through all frames 

        # read feed
        ret, frame = cap.read()

        # make detections 
        image, results = mediapipe_detection(frame, holistic)
        #print(results)

        #draw_landmarks(image, results)
        draw_styled_landmarks(image, results)

        # 2. Prediction logic
        keypoints = extract_keypoints(results) # extract keypoints x, y, z for face, left_hand, pose, right_hand from mediapipe holistic predictions, keypoints.shape e.g. (543, 3)
        sequence.append(keypoints) # keep appending keypoints (frames) to a sequence, np.array(sequence).shape e.g. (22, 543, 3)
        sequence = sequence[-LENGTH:] # takes last LENGTH frames of the sequence

        # 
        if len(sequence) == LENGTH: 
            # pre-processing
            model_input = feature_converter(np.array(sequence))
            #print(f'OMG! Frenzy Franzi is converting your mediapipe input! See how the shape is changing from {np.array(sequence).shape} to {model_input.shape}! SO AWESOME!!!')
            
            # prediction
            pred = model.predict(model_input)[0] # model.fit() expects something in shape (num_sequences, 30, 1662), e.g. (1, 30, 1662) for a single sequence
            selected_labels = [LABEL_MAP[x] for x in SELECTED_SIGNS]
            pred_all = pred 
            pred = pred[selected_labels]
            predictions.append(np.argmax(pred))
            #print(actions[np.argmax(res)])

            # 3. Visualization logic
            # makes sure the last x frames had the same prediction (more stable transition from one sign to another) 
            if np.unique(predictions[-TRANSITION_FRAMES:])[0]==np.argmax(pred): 
                # if the confidence of the most confident prediction is above threshold
                if pred[np.argmax(pred)] > threshold: 
                    # if there is already a last prediction
                    if len(sentence) > 0: 
                        # only append the predicted word, if it differs from the last prediction (prevent double actions)
                        if SELECTED_SIGNS[np.argmax(pred)] != sentence[-1]: 
                            sentence.append(SELECTED_SIGNS[np.argmax(pred)])
                    # just append if there is no last prediction (first prediction)
                    else: 
                        sentence.append(SELECTED_SIGNS[np.argmax(pred)])

            # limit the history to the last 5 predictions
            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # viz probabilities
            print(f'Example prediction for "{SELECTED_SIGNS[0]}": {pred[0]}')
            image = prob_viz(pred, SELECTED_SIGNS, image)

        # some rendering
        cv2.rectangle(image, (0, 0), (1280, 40), (200, 200, 200), -1)
        cv2.putText(image, ' '.join(sentence), (323,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (52, 75, 102), 2, cv2.LINE_AA)
        # cv2.putText(image, 'OpenCV', org, font, fontScale, color, thickness, cv2.LINE_AA)

        # show to screen
        cv2.imshow("OpenCV Feed", image)

        # break gracefully 
        if cv2.waitKey(10) & 0xFF == ord('q'): 
            break 
        
# release camera and close feed window 
cap.release()
cv2.destroyAllWindows() 
cv2.waitKey(1) # some workaround to fix the bug, that window doesn't close
# Out:
# 1/1 [==============================] - 0s 291ms/step
# Example prediction for "brown": 2.8681263512969656e-17
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "brown": 8.239021715306799e-16
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 6.623816705769942e-15
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 5.804308517653144e-15
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 8.941029916496954e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 6.927350433022928e-17
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "brown": 6.017046771586692e-17
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 8.475715245511336e-18
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 8.463250460860775e-18
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 3.4125410617130286e-18
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.9299859115787272e-17
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 4.660928163314591e-17
# 1/1 [==============================] - 0s 19ms/step
# Example prediction for "brown": 2.1079484271519172e-16
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.7359454870768865e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 4.822462441788559e-16
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.111336566195922e-15
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.862577170134213e-14
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 7.882447949567051e-14
# 1/1 [==============================] - 0s 20ms/step
# Example prediction for "brown": 9.380685925307677e-14
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 7.802047582213673e-14
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 7.592600728906565e-14
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 3.2144432786113813e-14
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.0194646301729844e-14
# 1/1 [==============================] - 0s 18ms/step
# Example prediction for "brown": 1.0425504919745767e-15
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.1245597190019256e-16
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.8279446134291652e-16
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.191140777545617e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.4951981263511905e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.520857616687214e-16
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.2704198850350673e-16
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 7.506117457969951e-16
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 6.326428202549285e-16
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 8.821738560765987e-16
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 7.898732052098896e-16
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.691287841827337e-16
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 7.496931120959182e-17
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.644379620429537e-17
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 5.438543120946706e-17
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 1.20643101200777e-16
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.674822364738167e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.062201021076166e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.0816908521457934e-16
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 2.4921554251859754e-16
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 4.628026028746335e-16
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.465821170855839e-16
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 1.0075183607115515e-16
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 6.668325772519093e-17
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.5474428538400397e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.1809786513246236e-15
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.977480577561048e-15
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 7.829866155904754e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.285300302409622e-16
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 7.873132598850503e-16
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.0511152656207385e-15
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 7.409252358308725e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.9825038078306085e-16
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.2992039174673405e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.050378770473101e-15
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.872135104421005e-15
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 2.017887437276867e-14
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 4.177416401619956e-14
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 4.5056301490329145e-14
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.4638717810947864e-14
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.8954301900264182e-14
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.3724317296233239e-14
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.3744375883457168e-14
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.2750202301836482e-14
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.0022346247731163e-14
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.4013121649929065e-14
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.601386411783726e-14
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.996284522035174e-14
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 9.579916375424772e-15
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 6.994963779246319e-16
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 6.748991764110774e-17
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 4.2916797009545947e-17
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.690794859044639e-17
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.646415989886361e-17
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 6.6124297043703124e-18
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.729184674595152e-17
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 6.965882491189119e-17
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.1232342447883706e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 9.774104257088871e-18
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.0714470474399367e-18
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.344332317088577e-19
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.1848376449325672e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.9516385978554175e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.8138897556519257e-25
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 8.80106967013729e-25
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.912512563697615e-24
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 5.74271250981094e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.3334070694998111e-20
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.1390768173343894e-20
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 9.37276413379275e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.1375295493414213e-21
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.213768803267227e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.0498981846893634e-21
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.354524629627934e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.2597555491307553e-32
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 0.0
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 0.0
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 4.133086567858417e-31
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 4.690372038333764e-27
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.5022044220457304e-25
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 8.122603498271671e-23
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.451766503312487e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.1486972820625146e-23
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.405287387116799e-23
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.6687304839067546e-23
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.0335806724154724e-22
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.0130029517128565e-23
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 7.215377899362205e-25
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 9.860051032299158e-27
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 5.687973088721638e-26
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.817307307629207e-24
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.3334413675942483e-24
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.648439324456487e-24
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 4.323112316489182e-28
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.506193273997439e-31
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.9180562074489377e-31
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "brown": 8.43364797878809e-30
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.390100129014403e-30
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.4601395775365064e-28
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.58199457692754e-24
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.109746328234141e-24
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.3574043192108302e-23
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.2522430703586398e-22
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.0692067935407245e-20
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.5404565160529428e-19
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.370135635840331e-19
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.5274791061820623e-18
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.92343096908293e-18
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.424166970054718e-18
# 1/1 [==============================] - 0s 156ms/step
# Example prediction for "brown": 3.983526054175214e-18
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.551599635260237e-18
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.2869410386949544e-18
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 8.843453069277657e-19
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.189463070896902e-19
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.5585428201464147e-19
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.0472176348285515e-19
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.3352092246359257e-19
# 1/1 [==============================] - 0s 18ms/step
# Example prediction for "brown": 1.0798112651495257e-19
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.467505777621272e-19
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.6225946461506634e-19
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.1843697062751066e-19
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.617339722815479e-19
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 6.22048932551312e-20
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 3.732237308252127e-20
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 4.5013957244785347e-20
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.3896038462355885e-19
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 1.8910558554608071e-19
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 2.581891512164895e-19
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "brown": 2.410991344720494e-19
# 1/1 [==============================] - 0s 20ms/step
# Example prediction for "brown": 1.318345855379325e-19
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 1.9623079655799032e-20
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.1509841791873183e-20
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 5.973918174800356e-21
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 9.971771336458286e-21
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 1.559737579143671e-20
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.1447876755146298e-20
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.623614784412553e-21
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 5.170188819237739e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.6803723041794716e-22
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.2419515596147315e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.286563347744535e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.7959312756477667e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.2719712385334719e-21
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 4.355782048307225e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 6.959531743535348e-21
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 6.219552042637392e-21
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 4.729063859489901e-21
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.3317877838259123e-21
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.90916799279255e-21
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.8209261129087235e-22
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 2.9843314863881955e-23
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 1.6876928071621777e-23
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "brown": 3.963913714942681e-23
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "brown": 1.6632807806980807e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 6.786576678503606e-22
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "brown": 4.679366379767446e-21
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "brown": 1.6275964392937097e-20
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 2.1445421553151574e-20
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.216424182280493e-20
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "brown": 6.984524876496667e-21
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "brown": 5.169312969062777e-21
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 7.42757379857258e-21
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 4.943987435395555e-21
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.8355024384107537e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 4.6922870378707525e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.7720895326893133e-22
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.438364640056996e-23
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.0306021226038927e-23
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.9900704496537196e-23
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.2154106177283314e-23
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 5.940483599064448e-23
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 9.84537284781232e-23
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 1.0186343143509084e-22
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 3.116653373799285e-22
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 1.3133079538638364e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.700590379679871e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 4.650208263174952e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 4.7102156121923425e-21
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.819212675288106e-21
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 7.551239117684783e-22
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 1.618792559740471e-22
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 2.4300453133106175e-23
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "brown": 9.944550176310697e-24
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.542279394375711e-23
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.699520356126255e-23
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.3252559022947945e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 4.478675116769427e-22
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 1.9903072215212562e-21
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "brown": 6.110209509312322e-21
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 8.05356453754839e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.47172785841082e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.5613266302588894e-21
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 5.210536593293769e-22
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "brown": 3.0789145205290016e-22
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 1.8189744079203343e-22
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.5595333285402686e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.5961224643728468e-22
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.301837303965819e-22
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.5924293331589642e-22
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "brown": 1.0737566958552594e-22
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "brown": 1.2790975681375233e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 6.510932269912556e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.32533452296797e-21
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 8.10081238327908e-21
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "brown": 8.588037112150586e-21
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 6.7703614343375095e-21
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.5567112699796642e-21
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 5.43441708524392e-22
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.7802419685627068e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.2517606978723565e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 5.42068661408975e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.7692607405920632e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 8.816418932778349e-21
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.6452607843395515e-20
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.4306721686916325e-20
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 2.1763328711423296e-20
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.7426123491775136e-20
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 9.283686313784879e-21
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.1020579894177848e-21
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.336968751063294e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.117250446841229e-23
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.405540137970791e-24
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 1.0238860374982815e-24
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "brown": 9.278713115335034e-25
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.0724742681674276e-24
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.573215560670043e-24
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.318499119134918e-23
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.552667461154294e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.2019504285308982e-20
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 9.648093785620439e-20
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 9.023218286443154e-20
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.5241931112343846e-19
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.499141495173349e-19
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.9594684096333735e-20
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 4.747992417623885e-19
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.2315174809274823e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 7.80666357296303e-14
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.0543137679086892e-13
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 9.31007370128618e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.3481184660784305e-18
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 7.323660171161143e-19
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.4002765123545765e-19
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 9.860617422994567e-18
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.182264931049576e-16
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.63176514981287e-16
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.9929227329708163e-15
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.4966755387661214e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.074220344776891e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.593645342582109e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.224570354922119e-14
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 4.535162100969701e-16
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.5560710704985827e-20
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.6228897178998762e-24
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.0051553565203369e-27
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 7.96598921357504e-21
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 6.018763959447782e-11
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.4084755548537942e-06
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.2779038938148801e-09
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.3912695995266233e-10
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.3947500272781799e-11
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 8.318183381678113e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.5524123870083728e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.032307265184552e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.518037675814557e-13
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.14087404502269e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.6181902712803366e-16
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.7912917262778675e-21
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.5213870314077996e-20
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.7922352066620495e-19
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.597940053734572e-15
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 7.348393811848486e-13
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 9.490983693405397e-11
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.4378083413538884e-13
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.1660348251188446e-12
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.9399386610996494e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.4787328047477736e-14
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 7.187920397777603e-11
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 8.360117220718166e-08
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 8.264949613590034e-09
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 6.559524590166177e-10
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.843317148024625e-14
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 8.610751695004026e-11
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 8.640623806732695e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.303641817915427e-11
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.5005298099365376e-11
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.1774196988798575e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.5484979958220163e-15
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.4487074488642236e-15
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.950105708766221e-13
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.8425213611783509e-13
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.396434349399135e-16
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.702180689156521e-15
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.432383349239899e-10
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.449529828447595e-10
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 8.144186713909818e-11
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 9.254519373058656e-10
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.085285499831002e-09
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.4109134827421386e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.346837560037509e-15
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.1779816899385603e-16
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.5835009633678227e-17
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.1038374756735585e-18
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.5024525499541173e-18
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.4290701480349902e-17
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 5.785933302532764e-16
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.5155630006888467e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.8591246977225223e-13
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 5.080769247163552e-13
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.1811725642713045e-12
# 1/1 [==============================] - 0s 39ms/step
# Example prediction for "brown": 3.1549251058859973e-12
# 1/1 [==============================] - 0s 19ms/step
# Example prediction for "brown": 5.9670619140250736e-12
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.5494946825503915e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.069308537456377e-13
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 8.508554375386695e-15
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.3432035239959917e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.410977689717761e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 4.6435193201428e-17
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.492952132464762e-17
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.0041304112210403e-17
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.084396031171405e-17
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.3313981177801494e-17
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.1237150683348355e-16
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.986438491256335e-15
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.0988008463178045e-12
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.0252565997332965e-11
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.670048257740875e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.7182612847678014e-15
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.6039908888852513e-17
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.242320361103294e-17
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 7.242811310615541e-17
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.1571717123360653e-17
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.8385624908438475e-19
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.0225940706552846e-18
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 6.864575448182095e-19
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.2571980316006726e-17
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.275176550114064e-15
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.380789742527061e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 5.947869421377844e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.6305942056663025e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 5.548001006495202e-15
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.9816758791038085e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 8.630131331788249e-12
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.924707504485923e-09
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.0561253954710637e-10
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.0438917390004007e-13
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.6696422850136514e-11
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 6.93034301821327e-12
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.3593324599617262e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 7.056891095785778e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.034984586037682e-12
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.3381911578846939e-08
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.5678066322143422e-06
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.1461823845593244e-07
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.7727269225351634e-11
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.740056007950354e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.2299943969471556e-11
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.107845911361982e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 5.436639636743901e-13
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.4702346588697936e-16
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.033059547995139e-17
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.78195430416625e-13
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.4267195281095213e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 7.687213495963241e-13
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 6.784764400693047e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.0409938698812543e-13
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 8.38203811914795e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.567335670971115e-12
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.357974263917042e-13
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.2608144976884364e-17
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 5.16521114752146e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.7406352265320637e-19
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 8.927275954318117e-17
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.858354668835072e-17
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.7652335534248415e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.349348895964518e-15
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.495445646926708e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.293258170909431e-13
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.127818742539647e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.49078685349491e-09
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.8357369501463836e-06
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.1888869266840629e-07
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.486584455534512e-08
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.5654638403114234e-10
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 7.15199233169983e-10
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 9.648336574130667e-10
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 4.974043954497631e-10
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 7.591122869188283e-11
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.4893841368546212e-11
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 1.1396234704617175e-13
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.0437524325737635e-12
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.2351845241065362e-11
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.5387162030644497e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 9.571215348058715e-12
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.8965868806009034e-11
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.6437901387278409e-12
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.2572651483980327e-17
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 9.290656587769216e-23
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.7418066140419443e-23
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 7.247351595420648e-23
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.6714904559586745e-20
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.141974439214307e-21
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.2539905990320548e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 9.224461635954502e-20
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.6872459196050717e-19
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.1133308252233508e-17
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.0843433225852305e-16
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.7481091448972543e-16
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 7.809487126356147e-20
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.378880189248394e-24
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 8.781211329443515e-26
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.8542161261098392e-18
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 6.328683914815295e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 6.518030559732324e-10
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.206996890270375e-10
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 9.365590247778499e-11
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.4111388652645468e-13
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.494327432677996e-20
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.393468445482755e-21
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 7.828802827635026e-19
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.8226116145839133e-14
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.316230304773569e-16
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 4.0494464036350373e-19
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.1298761405653668e-12
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.669474442525745e-13
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 6.062768083931249e-19
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.5075590069187288e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.117830166313082e-19
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 2.9660751599242366e-20
# 1/1 [==============================] - 0s 11ms/step
# ...
# Example prediction for "brown": 9.848126721789402e-25
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.9412726973481056e-24
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.3259926666457935e-23
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.3920288046675233e-24
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 6.451857301828671e-26
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.7972168106415303e-26
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 6.777608168175955e-26
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.4333704409122145e-24
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.6097249112907085e-24
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.1879972829097104e-25
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.807811890525989e-27
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.6172625063697857e-29
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 7.768014541329881e-29
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 6.772147155300046e-26
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.106393906585347e-24
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.6492568525670035e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.1825215063284109e-19
# 1/1 [==============================] - 0s 19ms/step
# Example prediction for "brown": 4.432554910468516e-20
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 4.7894690468390125e-21
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.9214416082487324e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.3235640414176154e-21
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 7.192668136123962e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 7.227328412379966e-23
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.164932569966574e-21
# 1/1 [==============================] - 0s 19ms/step
# Example prediction for "brown": 2.8978008603779595e-24
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 6.475514770449343e-28
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.667245808631086e-32
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.838468771158372e-28
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.5202077645127876e-28
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.4644396896339353e-26
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 9.916565135401268e-28
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 3.4219053039686335e-25
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.9189541781732355e-21
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 5.881448025708094e-21
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.9295520386766034e-23
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.6367303317857855e-25
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.838234759280312e-27
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 5.010545084154012e-28
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "brown": 2.3413388296582228e-28
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.0788322189740606e-27
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 8.58158514699668e-26
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.941528130149134e-24
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.5991780697575661e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.2460414689312786e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 4.496987292061121e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.89976386167447e-23
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 8.600824231879856e-24
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 6.877422985032603e-25
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 6.099193336364125e-26
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 9.515517572687836e-27
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.344758297371435e-27
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.812186140781607e-25
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.4830039757497333e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.128236565929526e-22
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 3.609316825295746e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 6.205061235788334e-23
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.725144388845216e-22
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.0885090258716165e-22
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 9.83315244575736e-23
# 1/1 [==============================] - 0s 21ms/step
# Example prediction for "brown": 1.577645574924143e-22
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 3.5291438186473036e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 4.456577418874632e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.1171342951415853e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.844257809960297e-22
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 7.290965728203014e-20
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.7002442557150408e-18
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 4.85743033521334e-21
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.525842473722885e-26
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.7927539382045013e-28
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.0532231089620622e-25
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "brown": 1.8804662880456352e-26
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "brown": 5.901447054136007e-28
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "brown": 8.101242250499852e-30
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.226139349433115e-30
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.570545779085417e-24
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.821729267793506e-23
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.114677813657122e-23
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 8.338464083160547e-24
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 7.785853016772161e-25
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 2.2391740373798227e-25
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 6.73460970216317e-26
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.595700420963281e-26
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.450246179694588e-26
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.7344346992019339e-25
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.954336884208689e-25
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.521959737325242e-25
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.079348209990719e-25
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 9.688538496659719e-27
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.1257072625427083e-27
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.3414505544980447e-27
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.4377625554534588e-28
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.37119074438673e-30
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.231247295565404e-30
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 3.404132334218587e-29
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 7.22786221059596e-29
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 7.217717374613901e-29
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 8.509883959614059e-30
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.7071254947952327e-30
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 6.8060191921084595e-31
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.2054111115708347e-31
# 1/1 [==============================] - 0s 19ms/step
# Example prediction for "brown": 5.611082399822442e-32
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 6.619623051238966e-32
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 3.3001830513918975e-32
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.598422818442349e-32
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 6.719886841892353e-33
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 5.205332900518885e-32
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "brown": 1.3931667523346748e-31
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 7.249016228258217e-32
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 7.932338000420524e-33
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.719500830426357e-33
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.667903644657165e-32
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.150951321820904e-31
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.0877848398356825e-32
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.2940096198176099e-33
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.5110372847190902e-33
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 9.081790743268282e-33
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 4.534004550281224e-32
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 9.140340794451596e-32
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 2.8117521594126605e-31
# 1/1 [==============================] - 0s 19ms/step
# Example prediction for "brown": 2.9466565930904295e-31
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.44337266312785e-32
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 5.0892252827263364e-33
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "brown": 1.521122603805863e-32
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 1.800347886208098e-31
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 1.057067526756605e-31
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 8.173031195137338e-32
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "brown": 1.5956981988612955e-31
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "brown": 3.3850792296493858e-28
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "brown": 9.022113426160875e-25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 16
#      13 ret, frame = cap.read()
#      15 # make detections
# ---> 16 image, results = mediapipe_detection(frame, holistic)
#      17 #print(results)
#      18
#      19 #draw_landmarks(image, results)
#      20 draw_styled_landmarks(image, results)
#
# Cell In[46], line 5, in mediapipe_detection(image, model)
#       3 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # color conversion BGR to RGB
#       4 image.flags.writeable = False                   # image no longer writeable
# ----> 5 results = model.process(image)                  # make prediction
#       6 image.flags.writeable = True                    # image is writeable again
#       7 image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)  # color conversion back to original
#
# File ~/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages/mediapipe/python/solutions/holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File ~/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages/mediapipe/python/solution_base.py:365, in SolutionBase.process(self, input_data)
#     359   else:
#     360     self._graph.add_packet_to_input_stream(
#     361         stream=stream_name,
#     362         packet=self._make_packet(input_stream_type,
#     363                                  data).at(self._simulated_timestamp))
# --> 365 self._graph.wait_until_idle()
#     366 # Create a NamedTuple object where the field names are mapping to the graph
#     367 # output stream names.
#     368 solution_outputs = collections.namedtuple(
#     369     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:

# %% [markdown]
# ## Next steps
#
# Save the recordings and predictions for later use?
#
# Add a feature, so that the user can type into a textbox to correct wrong prediction + real-time training / update of the model?
