# %% [markdown]
# # Modeling

# %% [markdown]
# ## Running Mode

# %%
MODE = 'training' # training model + evaluation
#MODE = 'evaluation' # loading existing model + evaluation

# %% [markdown]
# ## Reference

# %% [markdown]
# The code in this notebook is adapted and modified from the following Youtube tutorial: https://www.youtube.com/watch?v=doDUihpj6ro

# %% [markdown]
# ## Usage
#
# In this notebook, an LSTM based neural network model can be trained with data generated by the notebook "1_Example-Data-Generation.ipynb"
#
# The path to the input data `DATA_PATH` is set to 'MP_Data_test'. Change it, if you want to use different / your own data generated with "1_Example-Data-Generation.ipynb".
#
# The weights of the trained final model are saved with the name `model_name = 'first_model_whoop_whoop.h5'`. Change it, if you want ;)
#
# Further, weights are saved in checkpoints every 100 epochs (change if needed).

# %% [markdown]
# ## 1. Install and Import Dependencies

# %% [markdown]
# ### Install Dependencies

# %%
# %pip install tensorflow-macos opencv-python mediapipe-silicon sklearn matplotlib
#!pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 opencv-python mediapipe sklearn matplotlib # original code line from tutorial (he used a Windows system)
# Out:
# Requirement already satisfied: tensorflow-macos in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (2.12.0)
# Requirement already satisfied: opencv-python in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (4.7.0.72)
# Requirement already satisfied: mediapipe-silicon in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (0.9.1)
# Requirement already satisfied: sklearn in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (0.0.post1)
# Requirement already satisfied: matplotlib in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.12.0)
# Requirement already satisfied: setuptools in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (58.1.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.12.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.6.3)
# Requirement already satisfied: jax>=0.3.15 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (0.4.8)
# Requirement already satisfied: six>=1.12.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.16.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.14.1)
# Requirement already satisfied: packaging in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (23.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (16.0.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (23.3.3)
# Requirement already satisfied: h5py>=2.9.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (3.8.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.23.1)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.12.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (4.5.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.53.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (3.20.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (3.3.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from mediapipe-silicon) (22.2.0)
# Requirement already satisfied: opencv-contrib-python in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from mediapipe-silicon) (4.7.0.72)
# Requirement already satisfied: cycler>=0.10 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow-macos) (0.0.4)
# Requirement already satisfied: scipy>=1.7 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow-macos) (1.10.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (2.2.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (2.28.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (2.17.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (0.7.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-macos) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow-macos) (6.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-macos) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow-macos) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-macos) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import Dependencies

# %%
# general 
import math
import numpy as np
import pandas as pd
import os # easier file path handling

# for device camera feed
import cv2 # opencv
from matplotlib import pyplot as plt # imshow for easy visualization
import time # to insert breaks / "sleep" in between frames
import mediapipe as mp # for accessing and reading from device camera

# for data pre-processing
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# for model building and training
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# for model evaluation
from sklearn.metrics import multilabel_confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# %% [markdown]
# ## 2. Preprocess Data and Create Labels and Features

# %% [markdown]
# ### Some global setup (edit to your needs)

# %%
# path for input data
#DATA_PATH = os.path.join('MP_Data')
DATA_PATH = os.path.join('../data/')

# X and y filenames
X_fname = 'X-data.npy'
y_fname = 'y-data.npy'

# set random seed
RSEED = 24

# name for saving the trained model
model_name = 'Easter_model_10signs_j_test'

# directory to save tensorflow callbacks (logs)
log_dir = os.path.join('./Modeling_logs', model_name)

# for tensorboard callbacks
tb_callback = TensorBoard(log_dir=log_dir)

# for checkpoint callbacks
checkpoint_name = "cp-{epoch:04d}.ckpt"
checkpoint_path = os.path.join(log_dir, checkpoint_name)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
   filepath=checkpoint_path, 
   verbose=1, 
   save_weights_only=True,
   # Save weights, every 100 epochs 
   save_freq='epoch', 
   period=100)

# actions to detect (get later from our .json file)
#actions = np.array(['hello', 'thanks', 'iloveyou']) # from tutorial
actions = np.array ( ['alligator', 
                      'radio', 
                      'moon', 
                      'sleep', 
                      'grandpa', 
                      'tiger', 
                      'pencil', 
                      'sleepy', 
                      'grandma', 
                      'chocolate'] ) # from Ronja's kaggle example data

n_sequences = 30 # 30 videos per sequence / word / sign (get it later from input file?)
sequence_length = 30 # each video with 30 frames (get it later from input file?)
n_keypoints = 1086 # kaggle: 1086; tutorial: 1662

label_map = {label:num for num, label in enumerate(actions)} # create label map (dict, later our .json file)

if MODE == 'evaluation': 
   # path to existing model (or checkpoint) for evaluation
   #model_path = 'tutorial/Easter_model_10signs.h5'
   model_path = 'Modeling_logs/Easter_model_10signs_j_test/cp-0800.ckpt' # load model from checkpoint
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ### Load X and y Data

# %%
#loading our preprocessed kaggle data
X = np.load(os.path.join(DATA_PATH, X_fname))
y = np.load(os.path.join(DATA_PATH, y_fname))

# %% [markdown]
# ### Splitting Train and Test Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=RSEED)

# %% [markdown]
# ## Build and Train LSTM Neural Network

# %% [markdown]
# ### Setup Callbacks

# %% [markdown]
# ### Model building

# %%
# setup sequential model
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(n_sequences, n_keypoints))) # input_shape=(#sequences, #keypoints)
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax')) # actions.shape[0]: from user-defined actions (see above)

# compile the model
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# categorical_crossentropy must be used for multiclass classification model! 

# show summary of model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            294656
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 449,450
# Trainable params: 449,450
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model fitting

# %%
# fit the model if in training mode
if MODE == 'training': 
    # save model weight for every 100 epochs
    model.save_weights(checkpoint_path.format(epoch=10))

    model.fit(X_train, y_train, 
            epochs=2000, 
            callbacks=[tb_callback, cp_callback])
    # advantage of using mediapipe holistic model is you don't need additional data generator to build up a pipeline of data. Training data fits all into memory.
    # 2023-04-07-14-48 run-time: 17m 18.7s
    # 2023-04-09-18-36 run-time: , stopped at epoch: 

    # model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback, cp_callback], validation_data = (x_test, y_test), verbose=0)

# load an existing model if in evaluation mode
if MODE == 'evaluation': 
    # load model (or checkpoint) for evaluation
    model.load_weights(model_path)
# Out:
# Epoch 1/2000
# 2023-04-09 18:33:10.068654: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 10/10 [==============================] - 3s 44ms/step - loss: 2.3534 - categorical_accuracy: 0.1175
# Epoch 2/2000
# 10/10 [==============================] - 0s 38ms/step - loss: 2.2931 - categorical_accuracy: 0.0921
# Epoch 3/2000
# 10/10 [==============================] - 0s 37ms/step - loss: 2.2839 - categorical_accuracy: 0.1397
# Epoch 4/2000
# 10/10 [==============================] - 0s 38ms/step - loss: 2.2687 - categorical_accuracy: 0.1556
# Epoch 5/2000
# 10/10 [==============================] - 0s 38ms/step - loss: 2.2620 - categorical_accuracy: 0.1587
# Epoch 6/2000
# 10/10 [==============================] - 0s 37ms/step - loss: 2.2479 - categorical_accuracy: 0.1778
# Epoch 7/2000
# 10/10 [==============================] - 0s 36ms/step - loss: 2.2507 - categorical_accuracy: 0.1714
# Epoch 8/2000
# 10/10 [==============================] - 0s 35ms/step - loss: 2.2214 - categorical_accuracy: 0.1810
# Epoch 9/2000
# 10/10 [==============================] - 0s 37ms/step - loss: 2.2377 - categorical_accuracy: 0.1619
# Epoch 10/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 2.2647 - categorical_accuracy: 0.1778
# Epoch 11/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 2.2179 - categorical_accuracy: 0.1492
# Epoch 12/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 2.1876 - categorical_accuracy: 0.1714
# Epoch 13/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 2.1616 - categorical_accuracy: 0.1778
# Epoch 14/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 2.1732 - categorical_accuracy: 0.1937
# Epoch 15/2000
# 10/10 [==============================] - 0s 50ms/step - loss: 2.1469 - categorical_accuracy: 0.1968
# Epoch 16/2000
# 10/10 [==============================] - 1s 73ms/step - loss: 2.1609 - categorical_accuracy: 0.1714
# Epoch 17/2000
# 10/10 [==============================] - 1s 49ms/step - loss: 2.1440 - categorical_accuracy: 0.1841
# Epoch 18/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 2.1259 - categorical_accuracy: 0.2032
# Epoch 19/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 2.1025 - categorical_accuracy: 0.2063
# Epoch 20/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 2.1384 - categorical_accuracy: 0.1968
# Epoch 21/2000
# 10/10 [==============================] - 1s 51ms/step - loss: 2.1723 - categorical_accuracy: 0.2063
# Epoch 22/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 2.1169 - categorical_accuracy: 0.2317
# Epoch 23/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 2.1067 - categorical_accuracy: 0.1937
# Epoch 24/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 2.0869 - categorical_accuracy: 0.2159
# Epoch 25/2000
# 10/10 [==============================] - 0s 39ms/step - loss: 2.0941 - categorical_accuracy: 0.1778
# Epoch 26/2000
# 10/10 [==============================] - 0s 37ms/step - loss: 2.0955 - categorical_accuracy: 0.1937
# Epoch 27/2000
# 10/10 [==============================] - 0s 39ms/step - loss: 2.0764 - categorical_accuracy: 0.2317
# Epoch 28/2000
# 10/10 [==============================] - 0s 39ms/step - loss: 2.0947 - categorical_accuracy: 0.2000
# Epoch 29/2000
# 10/10 [==============================] - 0s 41ms/step - loss: 2.0917 - categorical_accuracy: 0.2095
# Epoch 30/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 2.0910 - categorical_accuracy: 0.2222
# Epoch 31/2000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.0652 - categorical_accuracy: 0.2317
# Epoch 32/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 2.0719 - categorical_accuracy: 0.2254
# Epoch 33/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 2.0566 - categorical_accuracy: 0.2063
# Epoch 34/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 2.0877 - categorical_accuracy: 0.1937
# Epoch 35/2000
# 10/10 [==============================] - 0s 41ms/step - loss: 2.0542 - categorical_accuracy: 0.2159
# Epoch 36/2000
# 10/10 [==============================] - 0s 40ms/step - loss: 2.0453 - categorical_accuracy: 0.2190
# Epoch 37/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 2.0174 - categorical_accuracy: 0.2127
# Epoch 38/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 2.0030 - categorical_accuracy: 0.2222
# Epoch 39/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 1.9560 - categorical_accuracy: 0.2413
# Epoch 40/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 1.9777 - categorical_accuracy: 0.2571
# Epoch 41/2000
# 10/10 [==============================] - 0s 41ms/step - loss: 1.9903 - categorical_accuracy: 0.2190
# Epoch 42/2000
# 10/10 [==============================] - 0s 41ms/step - loss: 2.0239 - categorical_accuracy: 0.2254
# Epoch 43/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 2.0182 - categorical_accuracy: 0.2508
# Epoch 44/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 1.8873 - categorical_accuracy: 0.3048
# Epoch 45/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 2.1050 - categorical_accuracy: 0.2444
# Epoch 46/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 1.9974 - categorical_accuracy: 0.2413
# Epoch 47/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 1.9652 - categorical_accuracy: 0.2794
# Epoch 48/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 1.8784 - categorical_accuracy: 0.3143
# Epoch 49/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.8249 - categorical_accuracy: 0.3079
# Epoch 50/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.8323 - categorical_accuracy: 0.3143
# Epoch 51/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.8642 - categorical_accuracy: 0.2857
# Epoch 52/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 1.7634 - categorical_accuracy: 0.3302
# Epoch 53/2000
# 10/10 [==============================] - 1s 66ms/step - loss: 1.6834 - categorical_accuracy: 0.3556
# Epoch 54/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 1.7378 - categorical_accuracy: 0.3778
# Epoch 55/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 3.1268 - categorical_accuracy: 0.3397
# Epoch 56/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 1.7417 - categorical_accuracy: 0.3746
# Epoch 57/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.6753 - categorical_accuracy: 0.3746
# Epoch 58/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 1.6468 - categorical_accuracy: 0.3683
# Epoch 59/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 1.7119 - categorical_accuracy: 0.3556
# Epoch 60/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 1.7920 - categorical_accuracy: 0.4032
# Epoch 61/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.6591 - categorical_accuracy: 0.3873
# Epoch 62/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 4.7320 - categorical_accuracy: 0.3429
# Epoch 63/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 2.0793 - categorical_accuracy: 0.3651
# Epoch 64/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 2.0500 - categorical_accuracy: 0.3619
# Epoch 65/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.7295 - categorical_accuracy: 0.3873
# Epoch 66/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.7562 - categorical_accuracy: 0.3429
# Epoch 67/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 1.6130 - categorical_accuracy: 0.3968
# Epoch 68/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.5382 - categorical_accuracy: 0.4190
# Epoch 69/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 1.5585 - categorical_accuracy: 0.4127
# Epoch 70/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 1.5378 - categorical_accuracy: 0.3841
# Epoch 71/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.4697 - categorical_accuracy: 0.4317
# Epoch 72/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 1.5532 - categorical_accuracy: 0.4413
# Epoch 73/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.5246 - categorical_accuracy: 0.4381
# Epoch 74/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 1.4587 - categorical_accuracy: 0.4730
# Epoch 75/2000
# 10/10 [==============================] - 1s 48ms/step - loss: 1.3850 - categorical_accuracy: 0.4540
# Epoch 76/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 1.4258 - categorical_accuracy: 0.4540
# Epoch 77/2000
# 10/10 [==============================] - 1s 64ms/step - loss: 1.4350 - categorical_accuracy: 0.4730
# Epoch 78/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 1.4058 - categorical_accuracy: 0.4952
# Epoch 79/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 1.4690 - categorical_accuracy: 0.4476
# Epoch 80/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 1.4501 - categorical_accuracy: 0.4571
# Epoch 81/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 1.3092 - categorical_accuracy: 0.4889
# Epoch 82/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 1.4028 - categorical_accuracy: 0.5143
# Epoch 83/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.2514 - categorical_accuracy: 0.5079
# Epoch 84/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.4153 - categorical_accuracy: 0.4698
# Epoch 85/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 1.4105 - categorical_accuracy: 0.4857
# Epoch 86/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.3230 - categorical_accuracy: 0.4921
# Epoch 87/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.2094 - categorical_accuracy: 0.5587
# Epoch 88/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.1928 - categorical_accuracy: 0.5556
# Epoch 89/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.3761 - categorical_accuracy: 0.5048
# Epoch 90/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.3393 - categorical_accuracy: 0.4730
# Epoch 91/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 1.2178 - categorical_accuracy: 0.5460
# Epoch 92/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 1.1499 - categorical_accuracy: 0.5619
# Epoch 93/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 1.1819 - categorical_accuracy: 0.5429
# Epoch 94/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.1792 - categorical_accuracy: 0.5683
# Epoch 95/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.1777 - categorical_accuracy: 0.5905
# Epoch 96/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 2.8680 - categorical_accuracy: 0.3175
# Epoch 97/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 3.3984 - categorical_accuracy: 0.1143
# Epoch 98/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 2.3744 - categorical_accuracy: 0.1079
# Epoch 99/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 2.2426 - categorical_accuracy: 0.1460
# Epoch 100/2000
#  9/10 [==========================>...] - ETA: 0s - loss: 2.2487 - categorical_accuracy: 0.1632
# Epoch 100: saving model to ./Modeling_logs/Easter_model_10signs_j_test/cp-0100.ckpt
# 10/10 [==============================] - 0s 48ms/step - loss: 2.2384 - categorical_accuracy: 0.1778
# Epoch 101/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 2.1791 - categorical_accuracy: 0.1587
# Epoch 102/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 2.1331 - categorical_accuracy: 0.1556
# Epoch 103/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 2.0560 - categorical_accuracy: 0.2190
# Epoch 104/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 2.2529 - categorical_accuracy: 0.1714
# Epoch 105/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 2.2300 - categorical_accuracy: 0.1587
# Epoch 106/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 2.1753 - categorical_accuracy: 0.1905
# Epoch 107/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 2.1691 - categorical_accuracy: 0.1651
# Epoch 108/2000
# 10/10 [==============================] - 1s 50ms/step - loss: 2.1417 - categorical_accuracy: 0.1905
# Epoch 109/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 2.0806 - categorical_accuracy: 0.2190
# Epoch 110/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 2.1594 - categorical_accuracy: 0.1714
# Epoch 111/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 2.2043 - categorical_accuracy: 0.2063
# Epoch 112/2000
# 10/10 [==============================] - 1s 55ms/step - loss: 2.1214 - categorical_accuracy: 0.1937
# Epoch 113/2000
# 10/10 [==============================] - 1s 47ms/step - loss: 2.0871 - categorical_accuracy: 0.2127
# Epoch 114/2000
# 10/10 [==============================] - 1s 55ms/step - loss: 2.0454 - categorical_accuracy: 0.2508
# Epoch 115/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 2.0198 - categorical_accuracy: 0.2127
# Epoch 116/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 2.0225 - categorical_accuracy: 0.2603
# Epoch 117/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 2.0267 - categorical_accuracy: 0.2127
# Epoch 118/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 1.9585 - categorical_accuracy: 0.3111
# Epoch 119/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 2.1974 - categorical_accuracy: 0.2381
# Epoch 120/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 2.3721 - categorical_accuracy: 0.1333
# Epoch 121/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 2.3318 - categorical_accuracy: 0.1111
# Epoch 122/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 2.2618 - categorical_accuracy: 0.1460
# Epoch 123/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 2.2085 - categorical_accuracy: 0.1397
# Epoch 124/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 2.1517 - categorical_accuracy: 0.1841
# Epoch 125/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 2.0950 - categorical_accuracy: 0.1905
# Epoch 126/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 2.0508 - categorical_accuracy: 0.2063
# Epoch 127/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 2.0289 - categorical_accuracy: 0.2635
# Epoch 128/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 2.0318 - categorical_accuracy: 0.2540
# Epoch 129/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 2.0728 - categorical_accuracy: 0.2063
# Epoch 130/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 1.9969 - categorical_accuracy: 0.2730
# Epoch 131/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 1.9442 - categorical_accuracy: 0.2857
# Epoch 132/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.9019 - categorical_accuracy: 0.3016
# Epoch 133/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 2.1723 - categorical_accuracy: 0.2317
# Epoch 134/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 2.0495 - categorical_accuracy: 0.2444
# Epoch 135/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 1.9916 - categorical_accuracy: 0.2635
# Epoch 136/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.9436 - categorical_accuracy: 0.2698
# Epoch 137/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.8827 - categorical_accuracy: 0.3111
# Epoch 138/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.8416 - categorical_accuracy: 0.3016
# Epoch 139/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.7979 - categorical_accuracy: 0.3587
# Epoch 140/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.7982 - categorical_accuracy: 0.3460
# Epoch 141/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.7485 - categorical_accuracy: 0.3397
# Epoch 142/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 1.6688 - categorical_accuracy: 0.4032
# Epoch 143/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.7458 - categorical_accuracy: 0.3333
# Epoch 144/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.7236 - categorical_accuracy: 0.3524
# Epoch 145/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.6406 - categorical_accuracy: 0.3841
# Epoch 146/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 1.6569 - categorical_accuracy: 0.3714
# Epoch 147/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.5680 - categorical_accuracy: 0.4317
# Epoch 148/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 1.5722 - categorical_accuracy: 0.4222
# Epoch 149/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 1.5692 - categorical_accuracy: 0.3873
# Epoch 150/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 1.5736 - categorical_accuracy: 0.4190
# Epoch 151/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 1.5526 - categorical_accuracy: 0.3937
# Epoch 152/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 1.5066 - categorical_accuracy: 0.4190
# Epoch 153/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.4967 - categorical_accuracy: 0.4286
# Epoch 154/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 1.4289 - categorical_accuracy: 0.4762
# Epoch 155/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 1.4039 - categorical_accuracy: 0.4762
# Epoch 156/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 1.5277 - categorical_accuracy: 0.4254
# Epoch 157/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.4746 - categorical_accuracy: 0.4317
# Epoch 158/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 1.3713 - categorical_accuracy: 0.4762
# Epoch 159/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.3957 - categorical_accuracy: 0.4476
# Epoch 160/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.3770 - categorical_accuracy: 0.4889
# Epoch 161/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.4351 - categorical_accuracy: 0.4476
# Epoch 162/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.3933 - categorical_accuracy: 0.4698
# Epoch 163/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 1.3407 - categorical_accuracy: 0.4889
# Epoch 164/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 1.5788 - categorical_accuracy: 0.4222
# Epoch 165/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 1.4481 - categorical_accuracy: 0.4635
# Epoch 166/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.3183 - categorical_accuracy: 0.5048
# Epoch 167/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.3200 - categorical_accuracy: 0.5175
# Epoch 168/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 1.2749 - categorical_accuracy: 0.5238
# Epoch 169/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.3195 - categorical_accuracy: 0.4952
# Epoch 170/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.4433 - categorical_accuracy: 0.4825
# Epoch 171/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 1.6108 - categorical_accuracy: 0.5270
# Epoch 172/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 1.2982 - categorical_accuracy: 0.5111
# Epoch 173/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.2979 - categorical_accuracy: 0.5333
# Epoch 174/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 1.2018 - categorical_accuracy: 0.5524
# Epoch 175/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.2429 - categorical_accuracy: 0.5524
# Epoch 176/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 1.3038 - categorical_accuracy: 0.5270
# Epoch 177/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.2871 - categorical_accuracy: 0.5079
# Epoch 178/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 1.2072 - categorical_accuracy: 0.5556
# Epoch 179/2000
# 10/10 [==============================] - 1s 50ms/step - loss: 1.1423 - categorical_accuracy: 0.5587
# Epoch 180/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 1.1655 - categorical_accuracy: 0.5778
# Epoch 181/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 1.4409 - categorical_accuracy: 0.4571
# Epoch 182/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 1.4754 - categorical_accuracy: 0.4603
# Epoch 183/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 1.3070 - categorical_accuracy: 0.5175
# Epoch 184/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.2382 - categorical_accuracy: 0.5238
# Epoch 185/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 1.0993 - categorical_accuracy: 0.6095
# Epoch 186/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.1302 - categorical_accuracy: 0.5746
# Epoch 187/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.1000 - categorical_accuracy: 0.5905
# Epoch 188/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.2227 - categorical_accuracy: 0.5270
# Epoch 189/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 1.1097 - categorical_accuracy: 0.5587
# Epoch 190/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.2022 - categorical_accuracy: 0.5619
# Epoch 191/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 1.1147 - categorical_accuracy: 0.5968
# Epoch 192/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.0234 - categorical_accuracy: 0.6222
# Epoch 193/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 1.2008 - categorical_accuracy: 0.5651
# Epoch 194/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 1.0664 - categorical_accuracy: 0.5937
# Epoch 195/2000
# 10/10 [==============================] - 1s 65ms/step - loss: 1.0311 - categorical_accuracy: 0.6317
# Epoch 196/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 1.0023 - categorical_accuracy: 0.6000
# Epoch 197/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 1.0647 - categorical_accuracy: 0.5841
# Epoch 198/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 1.0098 - categorical_accuracy: 0.6095
# Epoch 199/2000
# 10/10 [==============================] - 1s 62ms/step - loss: 0.9308 - categorical_accuracy: 0.6476
# Epoch 200/2000
# 10/10 [==============================] - ETA: 0s - loss: 0.8631 - categorical_accuracy: 0.6857
# Epoch 200: saving model to ./Modeling_logs/Easter_model_10signs_j_test/cp-0200.ckpt
# 10/10 [==============================] - 1s 54ms/step - loss: 0.8631 - categorical_accuracy: 0.6857
# Epoch 201/2000
# 10/10 [==============================] - 1s 62ms/step - loss: 0.7885 - categorical_accuracy: 0.7016
# Epoch 202/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.7301 - categorical_accuracy: 0.7302
# Epoch 203/2000
# 10/10 [==============================] - 1s 49ms/step - loss: 0.7741 - categorical_accuracy: 0.7048
# Epoch 204/2000
# 10/10 [==============================] - 1s 51ms/step - loss: 0.8199 - categorical_accuracy: 0.6889
# Epoch 205/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.7579 - categorical_accuracy: 0.7143
# Epoch 206/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.7909 - categorical_accuracy: 0.7016
# Epoch 207/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.8300 - categorical_accuracy: 0.6984
# Epoch 208/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 0.8897 - categorical_accuracy: 0.6730
# Epoch 209/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.8220 - categorical_accuracy: 0.6698
# Epoch 210/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.6683 - categorical_accuracy: 0.7746
# Epoch 211/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6329 - categorical_accuracy: 0.7619
# Epoch 212/2000
# 10/10 [==============================] - 0s 50ms/step - loss: 0.7462 - categorical_accuracy: 0.7175
# Epoch 213/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6691 - categorical_accuracy: 0.7365
# Epoch 214/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 0.6210 - categorical_accuracy: 0.7873
# Epoch 215/2000
# 10/10 [==============================] - 1s 49ms/step - loss: 0.6569 - categorical_accuracy: 0.7429
# Epoch 216/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.6835 - categorical_accuracy: 0.7619
# Epoch 217/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.6614 - categorical_accuracy: 0.7587
# Epoch 218/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.6580 - categorical_accuracy: 0.7524
# Epoch 219/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.6339 - categorical_accuracy: 0.7556
# Epoch 220/2000
# 10/10 [==============================] - 0s 41ms/step - loss: 0.6106 - categorical_accuracy: 0.7683
# Epoch 221/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.5368 - categorical_accuracy: 0.7905
# Epoch 222/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.5644 - categorical_accuracy: 0.7810
# Epoch 223/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.7559 - categorical_accuracy: 0.7429
# Epoch 224/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.8014 - categorical_accuracy: 0.7079
# Epoch 225/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.6827 - categorical_accuracy: 0.7365
# Epoch 226/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.5061 - categorical_accuracy: 0.8254
# Epoch 227/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.4557 - categorical_accuracy: 0.8444
# Epoch 228/2000
# 10/10 [==============================] - 1s 66ms/step - loss: 0.4580 - categorical_accuracy: 0.8286
# Epoch 229/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.4989 - categorical_accuracy: 0.7968
# Epoch 230/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.5840 - categorical_accuracy: 0.7810
# Epoch 231/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.8187 - categorical_accuracy: 0.6762
# Epoch 232/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 0.7899 - categorical_accuracy: 0.6921
# Epoch 233/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 0.6410 - categorical_accuracy: 0.7492
# Epoch 234/2000
# 10/10 [==============================] - 0s 50ms/step - loss: 0.4867 - categorical_accuracy: 0.8381
# Epoch 235/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.4391 - categorical_accuracy: 0.8317
# Epoch 236/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.4099 - categorical_accuracy: 0.8667
# Epoch 237/2000
# 10/10 [==============================] - 0s 50ms/step - loss: 0.4401 - categorical_accuracy: 0.8413
# Epoch 238/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.6272 - categorical_accuracy: 0.7873
# Epoch 239/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 0.6151 - categorical_accuracy: 0.7524
# Epoch 240/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.5682 - categorical_accuracy: 0.7905
# Epoch 241/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.6245 - categorical_accuracy: 0.7778
# Epoch 242/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 1.0852 - categorical_accuracy: 0.6190
# Epoch 243/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 1.0868 - categorical_accuracy: 0.5810
# Epoch 244/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.9576 - categorical_accuracy: 0.6444
# Epoch 245/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.8789 - categorical_accuracy: 0.6540
# Epoch 246/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.6534 - categorical_accuracy: 0.7524
# Epoch 247/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 0.5251 - categorical_accuracy: 0.8095
# Epoch 248/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.4113 - categorical_accuracy: 0.8635
# Epoch 249/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.3118 - categorical_accuracy: 0.9016
# Epoch 250/2000
# 10/10 [==============================] - 1s 62ms/step - loss: 0.2905 - categorical_accuracy: 0.8952
# Epoch 251/2000
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2675 - categorical_accuracy: 0.9143
# Epoch 252/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 0.3238 - categorical_accuracy: 0.9016
# Epoch 253/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.3172 - categorical_accuracy: 0.8921
# Epoch 254/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3373 - categorical_accuracy: 0.8762
# Epoch 255/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3539 - categorical_accuracy: 0.8667
# Epoch 256/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.3614 - categorical_accuracy: 0.8635
# Epoch 257/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.2833 - categorical_accuracy: 0.8952
# Epoch 258/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.5058 - categorical_accuracy: 0.8159
# Epoch 259/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.9407 - categorical_accuracy: 0.6762
# Epoch 260/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.7493 - categorical_accuracy: 0.7143
# Epoch 261/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.5583 - categorical_accuracy: 0.8032
# Epoch 262/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.4374 - categorical_accuracy: 0.8349
# Epoch 263/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.3807 - categorical_accuracy: 0.8508
# Epoch 264/2000
# 10/10 [==============================] - 1s 67ms/step - loss: 0.3496 - categorical_accuracy: 0.8635
# Epoch 265/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.2334 - categorical_accuracy: 0.9206
# Epoch 266/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.2093 - categorical_accuracy: 0.9270
# Epoch 267/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 0.1857 - categorical_accuracy: 0.9429
# Epoch 268/2000
# 10/10 [==============================] - 1s 54ms/step - loss: 0.1853 - categorical_accuracy: 0.9429
# Epoch 269/2000
# 10/10 [==============================] - 1s 55ms/step - loss: 0.2835 - categorical_accuracy: 0.9016
# Epoch 270/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.3922 - categorical_accuracy: 0.8571
# Epoch 271/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.3875 - categorical_accuracy: 0.8540
# Epoch 272/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.6202 - categorical_accuracy: 0.7778
# Epoch 273/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.9576 - categorical_accuracy: 0.6603
# Epoch 274/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.7132 - categorical_accuracy: 0.7365
# Epoch 275/2000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.5724 - categorical_accuracy: 0.7937
# Epoch 276/2000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.3678 - categorical_accuracy: 0.8825
# Epoch 277/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.3383 - categorical_accuracy: 0.8857
# Epoch 278/2000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.3892 - categorical_accuracy: 0.8730
# Epoch 279/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.3672 - categorical_accuracy: 0.8794
# Epoch 280/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.4763 - categorical_accuracy: 0.8413
# Epoch 281/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.4053 - categorical_accuracy: 0.8381
# Epoch 282/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 0.3711 - categorical_accuracy: 0.8794
# Epoch 283/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 0.2662 - categorical_accuracy: 0.9048
# Epoch 284/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.2189 - categorical_accuracy: 0.9238
# Epoch 285/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 0.2474 - categorical_accuracy: 0.9206
# Epoch 286/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1983 - categorical_accuracy: 0.9302
# Epoch 287/2000
# 10/10 [==============================] - 0s 50ms/step - loss: 0.2059 - categorical_accuracy: 0.9238
# Epoch 288/2000
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1906 - categorical_accuracy: 0.9365
# Epoch 289/2000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.1838 - categorical_accuracy: 0.9492
# Epoch 290/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 0.1883 - categorical_accuracy: 0.9397
# Epoch 291/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 0.1736 - categorical_accuracy: 0.9365
# Epoch 292/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.2054 - categorical_accuracy: 0.9238
# Epoch 293/2000
# 10/10 [==============================] - 1s 54ms/step - loss: 0.2530 - categorical_accuracy: 0.9111
# Epoch 294/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.2454 - categorical_accuracy: 0.9143
# Epoch 295/2000
# 10/10 [==============================] - 1s 55ms/step - loss: 0.2220 - categorical_accuracy: 0.9079
# Epoch 296/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 0.1839 - categorical_accuracy: 0.9365
# Epoch 297/2000
# 10/10 [==============================] - 1s 70ms/step - loss: 0.1712 - categorical_accuracy: 0.9397
# Epoch 298/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.2275 - categorical_accuracy: 0.9365
# Epoch 299/2000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.2256 - categorical_accuracy: 0.9111
# Epoch 300/2000
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3121 - categorical_accuracy: 0.8889
# Epoch 300: saving model to ./Modeling_logs/Easter_model_10signs_j_test/cp-0300.ckpt
# 10/10 [==============================] - 0s 48ms/step - loss: 0.2900 - categorical_accuracy: 0.8984
# Epoch 301/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 0.3209 - categorical_accuracy: 0.8762
# Epoch 302/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 0.3042 - categorical_accuracy: 0.8952
# Epoch 303/2000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.3271 - categorical_accuracy: 0.8825
# Epoch 304/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 0.3569 - categorical_accuracy: 0.8825
# Epoch 305/2000
# 10/10 [==============================] - 1s 54ms/step - loss: 0.3250 - categorical_accuracy: 0.8794
# Epoch 306/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 0.2442 - categorical_accuracy: 0.8952
# Epoch 307/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 0.2094 - categorical_accuracy: 0.9270
# Epoch 308/2000
# 10/10 [==============================] - 1s 55ms/step - loss: 0.2382 - categorical_accuracy: 0.9143
# Epoch 309/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.3809 - categorical_accuracy: 0.8698
# Epoch 310/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.7084 - categorical_accuracy: 0.7651
# Epoch 311/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.6051 - categorical_accuracy: 0.7778
# Epoch 312/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.4612 - categorical_accuracy: 0.8222
# Epoch 313/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.4184 - categorical_accuracy: 0.8413
# Epoch 314/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3529 - categorical_accuracy: 0.8730
# Epoch 315/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 0.2272 - categorical_accuracy: 0.9270
# Epoch 316/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.1606 - categorical_accuracy: 0.9492
# Epoch 317/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.1363 - categorical_accuracy: 0.9524
# Epoch 318/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.1364 - categorical_accuracy: 0.9460
# Epoch 319/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.1220 - categorical_accuracy: 0.9492
# Epoch 320/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.1206 - categorical_accuracy: 0.9683
# Epoch 321/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 0.1159 - categorical_accuracy: 0.9651
# Epoch 322/2000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.1446 - categorical_accuracy: 0.9524
# Epoch 323/2000
# 10/10 [==============================] - 1s 54ms/step - loss: 0.1664 - categorical_accuracy: 0.9460
# Epoch 324/2000
# 10/10 [==============================] - 0s 50ms/step - loss: 0.3112 - categorical_accuracy: 0.8952
# Epoch 325/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 0.3408 - categorical_accuracy: 0.8794
# Epoch 326/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 0.3143 - categorical_accuracy: 0.8762
# Epoch 327/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3427 - categorical_accuracy: 0.8635
# Epoch 328/2000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.3773 - categorical_accuracy: 0.8508
# Epoch 329/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.2631 - categorical_accuracy: 0.9016
# Epoch 330/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.2142 - categorical_accuracy: 0.9143
# Epoch 331/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.2113 - categorical_accuracy: 0.9270
# Epoch 332/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.2137 - categorical_accuracy: 0.9079
# Epoch 333/2000
# 10/10 [==============================] - 0s 41ms/step - loss: 0.3211 - categorical_accuracy: 0.8730
# Epoch 334/2000
# 10/10 [==============================] - 1s 50ms/step - loss: 0.4682 - categorical_accuracy: 0.8635
# Epoch 335/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.4874 - categorical_accuracy: 0.8444
# Epoch 336/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.4123 - categorical_accuracy: 0.8540
# Epoch 337/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.2739 - categorical_accuracy: 0.9048
# Epoch 338/2000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.1986 - categorical_accuracy: 0.9270
# Epoch 339/2000
# 10/10 [==============================] - 0s 41ms/step - loss: 0.1599 - categorical_accuracy: 0.9460
# Epoch 340/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.1893 - categorical_accuracy: 0.9270
# Epoch 341/2000
# 10/10 [==============================] - 1s 50ms/step - loss: 0.1748 - categorical_accuracy: 0.9270
# Epoch 342/2000
# 10/10 [==============================] - 1s 51ms/step - loss: 0.1673 - categorical_accuracy: 0.9365
# Epoch 343/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1445 - categorical_accuracy: 0.9397
# Epoch 344/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 0.1213 - categorical_accuracy: 0.9556
# Epoch 345/2000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.1350 - categorical_accuracy: 0.9651
# Epoch 346/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1235 - categorical_accuracy: 0.9524
# Epoch 347/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.1061 - categorical_accuracy: 0.9587
# Epoch 348/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.0780 - categorical_accuracy: 0.9651
# Epoch 349/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.0728 - categorical_accuracy: 0.9810
# Epoch 350/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.0673 - categorical_accuracy: 0.9778
# Epoch 351/2000
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0661 - categorical_accuracy: 0.9746
# Epoch 352/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0834 - categorical_accuracy: 0.9651
# Epoch 353/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.1409 - categorical_accuracy: 0.9429
# Epoch 354/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.2566 - categorical_accuracy: 0.9016
# Epoch 355/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.6527 - categorical_accuracy: 0.8222
# Epoch 356/2000
# 10/10 [==============================] - 1s 45ms/step - loss: 0.4439 - categorical_accuracy: 0.8349
# Epoch 357/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 0.2615 - categorical_accuracy: 0.9111
# Epoch 358/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 0.2542 - categorical_accuracy: 0.9048
# Epoch 359/2000
# 10/10 [==============================] - 1s 64ms/step - loss: 0.1679 - categorical_accuracy: 0.9397
# Epoch 360/2000
# 10/10 [==============================] - 1s 54ms/step - loss: 0.1313 - categorical_accuracy: 0.9524
# Epoch 361/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0940 - categorical_accuracy: 0.9810
# Epoch 362/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0930 - categorical_accuracy: 0.9683
# Epoch 363/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0747 - categorical_accuracy: 0.9778
# Epoch 364/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0634 - categorical_accuracy: 0.9778
# Epoch 365/2000
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0585 - categorical_accuracy: 0.9810
# Epoch 366/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.0547 - categorical_accuracy: 0.9714
# Epoch 367/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0474 - categorical_accuracy: 0.9841
# Epoch 368/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.0461 - categorical_accuracy: 0.9841
# Epoch 369/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0635 - categorical_accuracy: 0.9810
# Epoch 370/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.1138 - categorical_accuracy: 0.9587
# Epoch 371/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.1707 - categorical_accuracy: 0.9333
# Epoch 372/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.1629 - categorical_accuracy: 0.9333
# Epoch 373/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.1183 - categorical_accuracy: 0.9556
# Epoch 374/2000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.1080 - categorical_accuracy: 0.9524
# Epoch 375/2000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.1101 - categorical_accuracy: 0.9556
# Epoch 376/2000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.1521 - categorical_accuracy: 0.9429
# Epoch 377/2000
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2538 - categorical_accuracy: 0.9111
# Epoch 378/2000
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2560 - categorical_accuracy: 0.9175
# Epoch 379/2000
# 10/10 [==============================] - 1s 67ms/step - loss: 0.3138 - categorical_accuracy: 0.8889
# Epoch 380/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.4616 - categorical_accuracy: 0.8444
# Epoch 381/2000
# 10/10 [==============================] - 1s 51ms/step - loss: 0.5787 - categorical_accuracy: 0.8222
# Epoch 382/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.7291 - categorical_accuracy: 0.7810
# Epoch 383/2000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.7299 - categorical_accuracy: 0.7524
# Epoch 384/2000
# 10/10 [==============================] - 1s 54ms/step - loss: 0.4869 - categorical_accuracy: 0.8159
# Epoch 385/2000
# 10/10 [==============================] - 0s 40ms/step - loss: 0.3333 - categorical_accuracy: 0.8857
# Epoch 386/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.2033 - categorical_accuracy: 0.9492
# Epoch 387/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.1456 - categorical_accuracy: 0.9587
# Epoch 388/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.0996 - categorical_accuracy: 0.9810
# Epoch 389/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.0896 - categorical_accuracy: 0.9714
# Epoch 390/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0716 - categorical_accuracy: 0.9778
# Epoch 391/2000
# 10/10 [==============================] - 0s 41ms/step - loss: 0.0729 - categorical_accuracy: 0.9746
# Epoch 392/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0670 - categorical_accuracy: 0.9778
# Epoch 393/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0565 - categorical_accuracy: 0.9810
# Epoch 394/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.0946 - categorical_accuracy: 0.9651
# Epoch 395/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0827 - categorical_accuracy: 0.9683
# Epoch 396/2000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.0871 - categorical_accuracy: 0.9651
# Epoch 397/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 0.1347 - categorical_accuracy: 0.9492
# Epoch 398/2000
# 10/10 [==============================] - 1s 55ms/step - loss: 0.1185 - categorical_accuracy: 0.9460
# Epoch 399/2000
# 10/10 [==============================] - 1s 48ms/step - loss: 0.1057 - categorical_accuracy: 0.9619
# Epoch 400/2000
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0873 - categorical_accuracy: 0.9722
# Epoch 400: saving model to ./Modeling_logs/Easter_model_10signs_j_test/cp-0400.ckpt
# 10/10 [==============================] - 1s 74ms/step - loss: 0.0910 - categorical_accuracy: 0.9714
# Epoch 401/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.1828 - categorical_accuracy: 0.9333
# Epoch 402/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 0.2861 - categorical_accuracy: 0.9175
# Epoch 403/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 0.1968 - categorical_accuracy: 0.9365
# Epoch 404/2000
# 10/10 [==============================] - 1s 44ms/step - loss: 0.2650 - categorical_accuracy: 0.8984
# Epoch 405/2000
# 10/10 [==============================] - 0s 43ms/step - loss: 0.3002 - categorical_accuracy: 0.8825
# Epoch 406/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.2285 - categorical_accuracy: 0.9302
# Epoch 407/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.1504 - categorical_accuracy: 0.9524
# Epoch 408/2000
# 10/10 [==============================] - 0s 41ms/step - loss: 0.0923 - categorical_accuracy: 0.9746
# Epoch 409/2000
# 10/10 [==============================] - 0s 42ms/step - loss: 0.0709 - categorical_accuracy: 0.9778
# Epoch 410/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0657 - categorical_accuracy: 0.9810
# Epoch 411/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0549 - categorical_accuracy: 0.9841
# ...
# Epoch 1868/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 3.4035e-05 - categorical_accuracy: 1.0000
# Epoch 1869/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 3.3274e-05 - categorical_accuracy: 1.0000
# Epoch 1870/2000
# 10/10 [==============================] - 0s 45ms/step - loss: 3.2787e-05 - categorical_accuracy: 1.0000
# Epoch 1871/2000
# 10/10 [==============================] - 1s 59ms/step - loss: 3.2150e-05 - categorical_accuracy: 1.0000
# Epoch 1872/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 3.1605e-05 - categorical_accuracy: 1.0000
# Epoch 1873/2000
# 10/10 [==============================] - 1s 65ms/step - loss: 3.1161e-05 - categorical_accuracy: 1.0000
# Epoch 1874/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 3.0637e-05 - categorical_accuracy: 1.0000
# Epoch 1875/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 3.0229e-05 - categorical_accuracy: 1.0000
# Epoch 1876/2000
# 10/10 [==============================] - 1s 60ms/step - loss: 2.9832e-05 - categorical_accuracy: 1.0000
# Epoch 1877/2000
# 10/10 [==============================] - 1s 51ms/step - loss: 2.9366e-05 - categorical_accuracy: 1.0000
# Epoch 1878/2000
# 10/10 [==============================] - 1s 60ms/step - loss: 2.9045e-05 - categorical_accuracy: 1.0000
# Epoch 1879/2000
# 10/10 [==============================] - 1s 60ms/step - loss: 2.8573e-05 - categorical_accuracy: 1.0000
# Epoch 1880/2000
# 10/10 [==============================] - 1s 69ms/step - loss: 2.8262e-05 - categorical_accuracy: 1.0000
# Epoch 1881/2000
# 10/10 [==============================] - 1s 89ms/step - loss: 2.7862e-05 - categorical_accuracy: 1.0000
# Epoch 1882/2000
# 10/10 [==============================] - 1s 75ms/step - loss: 2.7513e-05 - categorical_accuracy: 1.0000
# Epoch 1883/2000
# 10/10 [==============================] - 1s 65ms/step - loss: 2.7276e-05 - categorical_accuracy: 1.0000
# Epoch 1884/2000
# 10/10 [==============================] - 1s 79ms/step - loss: 2.6847e-05 - categorical_accuracy: 1.0000
# Epoch 1885/2000
# 10/10 [==============================] - 1s 54ms/step - loss: 2.6545e-05 - categorical_accuracy: 1.0000
# Epoch 1886/2000
# 10/10 [==============================] - 1s 50ms/step - loss: 2.6311e-05 - categorical_accuracy: 1.0000
# Epoch 1887/2000
# 10/10 [==============================] - 0s 44ms/step - loss: 2.5954e-05 - categorical_accuracy: 1.0000
# Epoch 1888/2000
# 10/10 [==============================] - 1s 58ms/step - loss: 2.5548e-05 - categorical_accuracy: 1.0000
# Epoch 1889/2000
# 10/10 [==============================] - 1s 61ms/step - loss: 2.5246e-05 - categorical_accuracy: 1.0000
# Epoch 1890/2000
# 10/10 [==============================] - 1s 50ms/step - loss: 2.4893e-05 - categorical_accuracy: 1.0000
# Epoch 1891/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 2.4666e-05 - categorical_accuracy: 1.0000
# Epoch 1892/2000
# 10/10 [==============================] - 1s 50ms/step - loss: 2.4329e-05 - categorical_accuracy: 1.0000
# Epoch 1893/2000
# 10/10 [==============================] - 1s 58ms/step - loss: 2.4068e-05 - categorical_accuracy: 1.0000
# Epoch 1894/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 2.3739e-05 - categorical_accuracy: 1.0000
# Epoch 1895/2000
# 10/10 [==============================] - 1s 63ms/step - loss: 2.3506e-05 - categorical_accuracy: 1.0000
# Epoch 1896/2000
# 10/10 [==============================] - 1s 63ms/step - loss: 2.3185e-05 - categorical_accuracy: 1.0000
# Epoch 1897/2000
# 10/10 [==============================] - 1s 62ms/step - loss: 2.2921e-05 - categorical_accuracy: 1.0000
# Epoch 1898/2000
# 10/10 [==============================] - 1s 74ms/step - loss: 2.2661e-05 - categorical_accuracy: 1.0000
# Epoch 1899/2000
# 10/10 [==============================] - 1s 64ms/step - loss: 2.2387e-05 - categorical_accuracy: 1.0000
# Epoch 1900/2000
# 10/10 [==============================] - ETA: 0s - loss: 2.2193e-05 - categorical_accuracy: 1.0000
# Epoch 1900: saving model to ./Modeling_logs/Easter_model_10signs_j_test/cp-1900.ckpt
# 10/10 [==============================] - 1s 69ms/step - loss: 2.2193e-05 - categorical_accuracy: 1.0000
# Epoch 1901/2000
# 10/10 [==============================] - 1s 61ms/step - loss: 2.1821e-05 - categorical_accuracy: 1.0000
# Epoch 1902/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 2.1628e-05 - categorical_accuracy: 1.0000
# Epoch 1903/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 2.1300e-05 - categorical_accuracy: 1.0000
# Epoch 1904/2000
# 10/10 [==============================] - 1s 62ms/step - loss: 2.1090e-05 - categorical_accuracy: 1.0000
# Epoch 1905/2000
# 10/10 [==============================] - 1s 48ms/step - loss: 2.0792e-05 - categorical_accuracy: 1.0000
# Epoch 1906/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 2.0581e-05 - categorical_accuracy: 1.0000
# Epoch 1907/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 2.0365e-05 - categorical_accuracy: 1.0000
# Epoch 1908/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 2.0122e-05 - categorical_accuracy: 1.0000
# Epoch 1909/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 1.9827e-05 - categorical_accuracy: 1.0000
# Epoch 1910/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 1.9699e-05 - categorical_accuracy: 1.0000
# Epoch 1911/2000
# 10/10 [==============================] - 1s 75ms/step - loss: 1.9719e-05 - categorical_accuracy: 1.0000
# Epoch 1912/2000
# 10/10 [==============================] - 1s 65ms/step - loss: 4.3803 - categorical_accuracy: 0.5905
# Epoch 1913/2000
# 10/10 [==============================] - 1s 70ms/step - loss: 2.1860 - categorical_accuracy: 0.3841
# Epoch 1914/2000
# 10/10 [==============================] - 1s 58ms/step - loss: 1.6036 - categorical_accuracy: 0.4317
# Epoch 1915/2000
# 10/10 [==============================] - 1s 81ms/step - loss: 1.3463 - categorical_accuracy: 0.5365
# Epoch 1916/2000
# 10/10 [==============================] - 1s 59ms/step - loss: 1.0751 - categorical_accuracy: 0.6698
# Epoch 1917/2000
# 10/10 [==============================] - 1s 73ms/step - loss: 0.9372 - categorical_accuracy: 0.6794
# Epoch 1918/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 0.6944 - categorical_accuracy: 0.7841
# Epoch 1919/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 0.6131 - categorical_accuracy: 0.8095
# Epoch 1920/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.4437 - categorical_accuracy: 0.8667
# Epoch 1921/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3818 - categorical_accuracy: 0.8857
# Epoch 1922/2000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.3304 - categorical_accuracy: 0.8921
# Epoch 1923/2000
# 10/10 [==============================] - 0s 49ms/step - loss: 0.2660 - categorical_accuracy: 0.9111
# Epoch 1924/2000
# 10/10 [==============================] - 0s 46ms/step - loss: 0.2225 - categorical_accuracy: 0.9302
# Epoch 1925/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 0.1978 - categorical_accuracy: 0.9302
# Epoch 1926/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 0.1513 - categorical_accuracy: 0.9556
# Epoch 1927/2000
# 10/10 [==============================] - 1s 70ms/step - loss: 0.1163 - categorical_accuracy: 0.9714
# Epoch 1928/2000
# 10/10 [==============================] - 1s 63ms/step - loss: 0.1116 - categorical_accuracy: 0.9524
# Epoch 1929/2000
# 10/10 [==============================] - 1s 71ms/step - loss: 0.1222 - categorical_accuracy: 0.9746
# Epoch 1930/2000
# 10/10 [==============================] - 1s 63ms/step - loss: 0.1258 - categorical_accuracy: 0.9651
# Epoch 1931/2000
# 10/10 [==============================] - 1s 67ms/step - loss: 0.3424 - categorical_accuracy: 0.9429
# Epoch 1932/2000
# 10/10 [==============================] - 1s 77ms/step - loss: 0.4166 - categorical_accuracy: 0.8667
# Epoch 1933/2000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.5560 - categorical_accuracy: 0.8127
# Epoch 1934/2000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.4453 - categorical_accuracy: 0.8540
# Epoch 1935/2000
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3096 - categorical_accuracy: 0.8889
# Epoch 1936/2000
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2221 - categorical_accuracy: 0.9302
# Epoch 1937/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 0.1460 - categorical_accuracy: 0.9714
# Epoch 1938/2000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0940 - categorical_accuracy: 0.9778
# Epoch 1939/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0776 - categorical_accuracy: 0.9810
# Epoch 1940/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0530 - categorical_accuracy: 0.9873
# Epoch 1941/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0464 - categorical_accuracy: 0.9905
# Epoch 1942/2000
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0877 - categorical_accuracy: 0.9746
# Epoch 1943/2000
# 10/10 [==============================] - 1s 80ms/step - loss: 0.2534 - categorical_accuracy: 0.9683
# Epoch 1944/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1094 - categorical_accuracy: 0.9714
# Epoch 1945/2000
# 10/10 [==============================] - 1s 51ms/step - loss: 0.1345 - categorical_accuracy: 0.9556
# Epoch 1946/2000
# 10/10 [==============================] - 1s 64ms/step - loss: 0.1272 - categorical_accuracy: 0.9619
# Epoch 1947/2000
# 10/10 [==============================] - 1s 63ms/step - loss: 0.0677 - categorical_accuracy: 0.9841
# Epoch 1948/2000
# 10/10 [==============================] - 1s 72ms/step - loss: 0.0497 - categorical_accuracy: 0.9905
# Epoch 1949/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0404 - categorical_accuracy: 0.9905
# Epoch 1950/2000
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0338 - categorical_accuracy: 0.9873
# Epoch 1951/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0301 - categorical_accuracy: 0.9905
# Epoch 1952/2000
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0254 - categorical_accuracy: 0.9937
# Epoch 1953/2000
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0244 - categorical_accuracy: 0.9937
# Epoch 1954/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0250 - categorical_accuracy: 0.9937
# Epoch 1955/2000
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0224 - categorical_accuracy: 0.9937
# Epoch 1956/2000
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0184 - categorical_accuracy: 0.9937
# Epoch 1957/2000
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0195 - categorical_accuracy: 0.9937
# Epoch 1958/2000
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0181 - categorical_accuracy: 0.9937
# Epoch 1959/2000
# 10/10 [==============================] - 1s 67ms/step - loss: 0.0188 - categorical_accuracy: 0.9937
# Epoch 1960/2000
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0179 - categorical_accuracy: 0.9937
# Epoch 1961/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0161 - categorical_accuracy: 0.9937
# Epoch 1962/2000
# 10/10 [==============================] - 1s 69ms/step - loss: 0.0164 - categorical_accuracy: 0.9937
# Epoch 1963/2000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.0141 - categorical_accuracy: 0.9937
# Epoch 1964/2000
# 10/10 [==============================] - 1s 63ms/step - loss: 0.0148 - categorical_accuracy: 0.9937
# Epoch 1965/2000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0139 - categorical_accuracy: 0.9937
# Epoch 1966/2000
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0131 - categorical_accuracy: 0.9937
# Epoch 1967/2000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0127 - categorical_accuracy: 0.9937
# Epoch 1968/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0117 - categorical_accuracy: 0.9937
# Epoch 1969/2000
# 10/10 [==============================] - 1s 49ms/step - loss: 0.0112 - categorical_accuracy: 0.9968
# Epoch 1970/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0109 - categorical_accuracy: 0.9937
# Epoch 1971/2000
# 10/10 [==============================] - 1s 50ms/step - loss: 0.0108 - categorical_accuracy: 0.9968
# Epoch 1972/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0103 - categorical_accuracy: 0.9968
# Epoch 1973/2000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.0109 - categorical_accuracy: 0.9937
# Epoch 1974/2000
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0106 - categorical_accuracy: 0.9968
# Epoch 1975/2000
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0102 - categorical_accuracy: 0.9937
# Epoch 1976/2000
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0093 - categorical_accuracy: 0.9968
# Epoch 1977/2000
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0100 - categorical_accuracy: 0.9937
# Epoch 1978/2000
# 10/10 [==============================] - 1s 65ms/step - loss: 0.0082 - categorical_accuracy: 0.9968
# Epoch 1979/2000
# 10/10 [==============================] - 1s 67ms/step - loss: 0.0081 - categorical_accuracy: 0.9968
# Epoch 1980/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0077 - categorical_accuracy: 0.9968
# Epoch 1981/2000
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0075 - categorical_accuracy: 0.9968
# Epoch 1982/2000
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0077 - categorical_accuracy: 0.9968
# Epoch 1983/2000
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0067 - categorical_accuracy: 1.0000
# Epoch 1984/2000
# 10/10 [==============================] - 1s 62ms/step - loss: 0.0048 - categorical_accuracy: 1.0000
# Epoch 1985/2000
# 10/10 [==============================] - 1s 65ms/step - loss: 0.0050 - categorical_accuracy: 0.9968
# Epoch 1986/2000
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0177 - categorical_accuracy: 0.9937
# Epoch 1987/2000
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0177 - categorical_accuracy: 0.9873
# Epoch 1988/2000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.2094 - categorical_accuracy: 0.9619
# Epoch 1989/2000
# 10/10 [==============================] - 1s 76ms/step - loss: 0.1520 - categorical_accuracy: 0.9556
# Epoch 1990/2000
# 10/10 [==============================] - 1s 72ms/step - loss: 0.1919 - categorical_accuracy: 0.9397
# Epoch 1991/2000
# 10/10 [==============================] - 1s 63ms/step - loss: 0.2644 - categorical_accuracy: 0.9302
# Epoch 1992/2000
# 10/10 [==============================] - 1s 70ms/step - loss: 0.2738 - categorical_accuracy: 0.9175
# Epoch 1993/2000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.2926 - categorical_accuracy: 0.8794
# Epoch 1994/2000
# 10/10 [==============================] - 1s 73ms/step - loss: 0.1912 - categorical_accuracy: 0.9460
# Epoch 1995/2000
# 10/10 [==============================] - 1s 58ms/step - loss: 0.1252 - categorical_accuracy: 0.9429
# Epoch 1996/2000
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0935 - categorical_accuracy: 0.9746
# Epoch 1997/2000
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0523 - categorical_accuracy: 0.9810
# Epoch 1998/2000
# 10/10 [==============================] - 1s 51ms/step - loss: 0.2987 - categorical_accuracy: 0.9746
# Epoch 1999/2000
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0505 - categorical_accuracy: 0.9905
# Epoch 2000/2000
# 10/10 [==============================] - ETA: 0s - loss: 0.0805 - categorical_accuracy: 0.9841
# Epoch 2000: saving model to ./Modeling_logs/Easter_model_10signs_j_test/cp-2000.ckpt
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0805 - categorical_accuracy: 0.9841

# %% [markdown]
# ### Tensorboard

# %% [markdown]
# Follow these steps to look at the model training (also possible in real-time):
#
# 1. Open the command palette (command+shift+P) in VSCode.
# 2. Type in "Python: Launch TensorBoard".
# 3. Press "Enter".
# 4. Click "Use current working directory" (select another option, if you want to look at logs outside the working directory)
# 5. If "No dashboards are active for the current data set.", click on the circular arrow in the top right to refresh the dashboard.
# 6. In the main dashboard area, you should immediately see plots showing the development of accuracies and losses per epoch.
# 7. In the left area you can check and uncheck log files that you want to add or remove from the plots.

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Optional: Load Checkpoint Model

# %%
#checkpoint_path = 'Modeling_logs/Easter_model_10signs_j_test/cp-0800.ckpt'
#model.load_weights(checkpoint_path)

# %% [markdown]
# ### Predict on test data

# %%
# prediction on test data
y_pred = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 469ms/step

# %% [markdown]
# ### Looking at a single example prediction

# %%
actions[np.argmax(y_pred[0])] # prediction
# Out:
# 'pencil'

# %%
actions[np.argmax(y_test[0])] # actual
# Out:
# 'pencil'

# %% [markdown]
# ## Evaluation using Accuracy and Confusion Matrix

# %% [markdown]
# ### Back-converting one-hot codes to labels

# %%
# convert one-hot encoded categories back to labels, 
# e.g. 0, 1 and 2 instead of [1,0,0], [0,1,0], [0,0,1]
y_test_original = y_test.copy()
y_test = np.argmax(y_test, axis=1).tolist()

# %%
y_pred_original = y_pred.copy()
y_pred = np.argmax(y_pred, axis=1).tolist()

# %% [markdown]
# ### Accuracy Score

# %%
# accuracy score
accuracy_score(y_test, y_pred)
# Out:
# 0.6470588235294118

# %% [markdown]
# ### Multilabel Confusion Matrix

# %%
# multilabel confusion matrix 
mcm = multilabel_confusion_matrix(y_test, y_pred)

# %%
# plotting parameters
labels = np.unique(y_pred) # labels, that are among predictions
ncols = 3 # define plot matrix columns always as 3 
nrows = math.ceil(len(labels)/ncols) # define rows depending on the number of labels / categories

# formatting plotting area
f, axes = plt.subplots(nrows, ncols, figsize=(nrows*3, ncols*3)) # define plot area layout based on pre-defined number of columns and rows
f.text(x=-0.05, y=0.995, 
       s='Test Accuracy Score: {:.4f}'.format(accuracy_score(y_test, y_pred)), 
       fontsize=18) # set plot title to accuracy score in top-left corner
f.tight_layout() # removes some whitespace
axes = axes.ravel() # flatten axes object to later access it as axes[i] with i indicating the heatmap number

# loop over all available categories / labels to plot each confusion matrix
for cat, i in zip(actions[labels], range(len(actions[labels]))): 
    
    # plot current confusion matrix heatmap
    disp = ConfusionMatrixDisplay(mcm[i], display_labels=[0, cat]) # creates confusion matrix display object with categories as labels for positive class and 0 for negative class
    disp.plot(ax=axes[i]) # plot confusion matrix heatmap into corresponding plat matrix position
    disp.ax_.set_title(f'class "{cat}"') # set title for each heatmap as 'class "class name"'

    # formatting single confusion matrix heatmaps
    #if i<len(actions[labels])-ncols: 
    #    disp.ax_.set_xlabel('') # display x label ("Predicted Label") only if it is the last row
    if i%ncols!=0: 
        disp.ax_.set_ylabel('') # display y label ("True Label") only if it is the first column (plot) in each row
    disp.im_.colorbar.remove() # removes all the extra colorbars for each heatmap

# final plotting
plt.subplots_adjust(wspace=0.75) # sets some width spacing
plt.colorbar(disp.im_, ax=axes) # adds one colobar for all heatmaps topether
plt.show()

# %% [markdown]
# ## Save Model Weights

# %%
# save model if in training mode
if MODE == 'training': 
    model.save(model_name+'.h5')

# %% [markdown]
# ## Next Steps
