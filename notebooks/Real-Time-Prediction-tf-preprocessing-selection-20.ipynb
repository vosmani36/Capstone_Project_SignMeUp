# %% [markdown]
# # Real-Time Prediction

# %% [markdown]
# ## Reference

# %% [markdown]
# The code in this notebook is adapted and modified from the following Youtube tutorial: https://www.youtube.com/watch?v=doDUihpj6ro

# %% [markdown]
# ## Usage

# %% [markdown]
# With this notebook, real-time predictions can be made on signs you perform in front of your running webcam.
#
# ### <span style="color:green">Quick User Guide:
#
# <span style="color:green">1. Load your trained TF Model.</span>
#
# <span style="color:green">2. Copy + paste used Configurations from Franziska's pre-processing notebook</span>
#
# <span style="color:green">Optional: 3. Copy + paste used Pre-processing Layer from Franziska's pre-processing notebook</span>

# %% [markdown]
# ## Install and Import Dependencies

# %% [markdown]
# ### Install Dependencies

# %%
# %pip install tensorflow-macos opencv-python mediapipe-silicon sklearn matplotlib
#!pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 opencv-python mediapipe sklearn matplotlib # original code line from tutorial (he had a windows system)
# Out:
# Requirement already satisfied: tensorflow-macos in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (2.12.0)
# Requirement already satisfied: opencv-python in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (4.7.0.72)
# Requirement already satisfied: mediapipe-silicon in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (0.9.1)
# Requirement already satisfied: sklearn in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (0.0.post4)
# Requirement already satisfied: matplotlib in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (0.4.8)
# Requirement already satisfied: libclang>=13.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (3.3.0)
# Requirement already satisfied: packaging in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (3.20.3)
# Requirement already satisfied: setuptools in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (1.54.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorflow-macos) (2.12.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from mediapipe-silicon) (23.1.0)
# Requirement already satisfied: opencv-contrib-python in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from mediapipe-silicon) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos) (0.40.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow-macos) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow-macos) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (2.28.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow-macos) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-macos) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow-macos) (6.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-macos) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-macos) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-macos) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/jin-holee/neuefische/Capstone_Project_SignMeUp/.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-macos) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import Dependencies

# %%
# general
import numpy as np
import pandas as pd
import os # easier file path handling

# for camera feed
import cv2 # opencv
from matplotlib import pyplot as plt # imshow for easy visualization
import time # to insert "sleep" in between frames
import mediapipe as mp # for accessing and reading from webcam

# for model re-building
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# for loading .json dictionary
import json

# %% [markdown]
# ## <span style="color:green">Load Files</span>

# %% [markdown]
# ### <span style="color:green">Load Saved Model</span>
#
# #### <span style="color:green">Here, you can load your trained TensorFlow model, e.g. LSTM.</span>

# %%
# load model
model = tf.keras.models.load_model('../models/LSTM_model_20signs_7.h5')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %% [markdown]
# ### Load sign_to_prediction_index_map.json file

# %%
# label map dictionary 
#LABEL_MAP = json.load(open("../data/asl-signs/sign_to_prediction_index_map.json", "r")) 
LABEL_MAP = {'brown': 0,  'callonphone': 1,  'cow': 2,  'cry': 3,  'dad': 4,  'fireman': 5,  'frog': 6,  'gum': 7,  'icecream': 8,  'minemy': 9,  'nose': 10,  'owl': 11,  'please': 12,  'radio': 13,  'shhh': 14,  'shirt': 15,  'tomorrow': 16,  'uncle': 17,  'water': 18,  'who': 19}

# %%
list(LABEL_MAP.keys())
# Out:
# ['brown',
#  'callonphone',
#  'cow',
#  'cry',
#  'dad',
#  'fireman',
#  'frog',
#  'gum',
#  'icecream',
#  'minemy',
#  'nose',
#  'owl',
#  'please',
#  'radio',
#  'shhh',
#  'shirt',
#  'tomorrow',
#  'uncle',
#  'water',
#  'who']

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Game Mechanics

# %%
COUNTDOWN = 0
#SELECTED_SIGNS = ['hello', 'mom', 'dad', 'hungry', 'thirsty']
#SELECTED_SIGNS = ['apple', 'bath', 'owl', 'clown', 'better']
SELECTED_SIGNS = list(LABEL_MAP.keys())

# %% [markdown]
# ### <span style="color:green">Franziskas's Configuration :) </span>

# %% [markdown]
# #### <span style="color:green">For now, just copy + paste the "Configuration" cell from Franziska's notebook "TF_Load-PreprocessData.ipynb" into the following cell :D </span>
#
# #### <span style="color:green">These configuration must be the same ones, which you used to preprocess the data to train the TensorFlow model, which you loaded above! </span>

# %%
#limit dataset for quick test
QUICK_TEST = True
QUICK_LIMIT = 500

#Define length of sequences for padding or cutting; 22 is the median length of all sequences
LENGTH = 22

#define min or max length of sequences; sequences too long/too short will be dropped
#max value of 92 was defined by calculating the interquartile range
MIN_LENGTH = 10
MAX_LENGTH = 92

#final data will be flattened, if false data will be 3 dimensional
FLATTEN = False

#define initialization of numpy array 
ARRAY = False #(True=Zeros, False=empty values)

#Define padding mode 
#1 = padding at start&end; 2 = padding at end; 3 = no padding, 4 = copy first/lastframe, 5 = copy last frame)
#Note: Mode 3 will give you an error due to different lengths, working on that
PADDING = 2
CONSTANT_VALUE = 0 #only required for mode 1 and 2; enter tf.constant(float('nan')) for NaN

#define if z coordinate will be dropped
DROP_Z = True

#mirror, flips x coordinate for data augmentation
MIRROR = True

#define if csv file should be filtered
CSV_FILTER  = False
#define how many participants for test set
TEST_COUNT = 5 #5 participants account for ca 23% of dataset
#generate test or train dataset (True = Train dataset; False = Test dataset)
#TRAIN = True #only works if CSV_FILTER is activated
TRAIN = True

#filter for specific signs
SIGN_FILTER = True
sign_list = [0,1,5,8]

#define filenames for x and y:
feature_data = 'X' #x data
feature_labels = 'y' #y data

#use for test dataset
#feature_data = 'X_test_h6' #x data
#feature_labels = 'y_test_h6' #y data


RANDOM_STATE = 42

#Defining Landmarks
#index ranges for each landmark type
#dont change these landmarks
FACE = list(range(0, 468))
LEFT_HAND = list(range(468, 489))
POSE = list(range(489, 522))
POSE_UPPER = list(range(489, 510))
RIGHT_HAND = list(range(522, 543))
LIPS = [61, 185, 40, 39, 37,  0, 267, 269, 270, 409,
                 291,146, 91,181, 84, 17, 314, 405, 321, 375, 
                 78, 191, 80, 81, 82, 13, 312, 311, 310, 415, 
                 95, 88, 178, 87, 14,317, 402, 318, 324, 308]
lipsUpperOuter= [61, 185, 40, 39, 37, 0, 267, 269, 270, 409, 291]
lipsLowerOuter= [146, 91, 181, 84, 17, 314, 405, 321, 375, 291]
lipsUpperInner= [78, 191, 80, 81, 82, 13, 312, 311, 310, 415, 308]
lipsLowerInner= [78, 95, 88, 178, 87, 14, 317, 402, 318, 324, 308]
#defining landmarks that will be merged
averaging_sets = []

#generating list with all landmarks selected for preprocessing
#change landmarks you want to use here:
point_landmarks_right = RIGHT_HAND + lipsUpperInner + lipsLowerInner
point_landmarks_left = LEFT_HAND + lipsUpperInner + lipsLowerInner

#calculating sum of total landmarks used
LANDMARKS = len(point_landmarks_right) + len(averaging_sets)
print(f'Total count of used landmarks: {LANDMARKS}')

#defining input shape for model
if DROP_Z:
    INPUT_SHAPE = (LENGTH,LANDMARKS*2)
else:
    INPUT_SHAPE = (LENGTH,LANDMARKS*3)
print(INPUT_SHAPE)
# Out:
# Total count of used landmarks: 43
# (22, 86)

# %%
print(f'Total count of used landmarks: {LANDMARKS}')
print(INPUT_SHAPE)
# Out:
# Total count of used landmarks: 43
# (22, 86)

# %% [markdown]
# ### Visualization

# %%
TRANSITION_FRAMES = LENGTH

# %% [markdown]
# ### Objects and Functions for MP Holistic Keypoints

# %% [markdown]
# #### Initialize MP Holistic Model

# %%
mp_holistic = mp.solutions.holistic # holistic model
mp_drawing = mp.solutions.drawing_utils # drawing utilities

# %% [markdown]
# #### Define Functions (later they all go into a python module for multiple use)

# %% [markdown]
# ##### mediapipe_detection()

# %%
# function to detect MP Holistic landmarks from an image, e.g. frames of your camera feed
def mediapipe_detection(image, model): 
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # color conversion BGR to RGB
    image.flags.writeable = False                   # image no longer writeable
    results = model.process(image)                  # make prediction
    image.flags.writeable = True                    # image is writeable again
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)  # color conversion back to original
    return image, results

# %% [markdown]
# ##### draw_styled_landmarks()

# %%
# function to draw landmarks points and connecting lines on top of an image, e.g. on top of your camera feed
def draw_styled_landmarks(image, results): 
    # draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                              mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                              mp_drawing.DrawingSpec(color=(224,208,64), thickness=1, circle_radius=1))
    # draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                              mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                              mp_drawing.DrawingSpec(color=(224,208,64), thickness=2, circle_radius=2)) 
    # draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                              mp_drawing.DrawingSpec(color=(224,208,64), thickness=2, circle_radius=4), 
                              mp_drawing.DrawingSpec(color=(235,206,135), thickness=2, circle_radius=2)) 
    # draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                              mp_drawing.DrawingSpec(color=(224,208,64), thickness=2, circle_radius=4), 
                              mp_drawing.DrawingSpec(color=(128,128,240), thickness=2, circle_radius=2))

# %% [markdown]
# ##### extract_keypoints()

# %%
# function to extract coordinates (+visibility) of all landmarks --> keypoints
# and concatenates everything into a flattened list 
def extract_keypoints(results): 
    face = np.array([[r.x, r.y, r.z] for r in results.face_landmarks.landmark]) if results.face_landmarks else np.zeros([468, 3])
    left_hand = np.array([[r.x, r.y, r.z] for r in results.left_hand_landmarks.landmark]) if results.left_hand_landmarks else np.zeros([21, 3])
    pose = np.array([[r.x, r.y, r.z] for r in results.pose_landmarks.landmark]) if results.pose_landmarks else np.zeros([33, 3]) # x, y, z and extra value visibility
    right_hand = np.array([[r.x, r.y, r.z] for r in results.right_hand_landmarks.landmark]) if results.right_hand_landmarks else np.zeros([21, 3])
    return np.concatenate([face, pose, left_hand, right_hand]) # original code
    # a flattened list with list of all pose, face, left_hand, right_hand landmark x, y, z, (+visibility) coordinates

# %% [markdown]
# ##### prob_viz()

# %%
# function to visualize predicted word probabilities with a dynamic real-time bar chart
def prob_viz(pred, image, SELECTED_SIGNS): 
    output_frame = image.copy() 
    bar_zero = 15
    
    for num, prob in enumerate(pred): 
        cv2.rectangle(output_frame, 
                      pt1=(bar_zero, 75+num*30), 
                      pt2=(bar_zero+int(prob*100), 95+num*30), 
                      color=(200, 200, 200), thickness=-1)
        # cv2.rectangle(image, start_point, end_point, color, thickness)
        cv2.putText(img=output_frame, 
                    text=SELECTED_SIGNS[num], 
                    org=(bar_zero, 95+num*30), 
                    fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=0.75, 
                    color=(50, 50, 50), 
                    thickness=1, lineType=cv2.LINE_AA)
        # cv2.putText(image, 'OpenCV', org, font, fontScale, color, thickness, cv2.LINE_AA)
    return output_frame

# %% [markdown]
# ## <span style="color:green">Pre-processing Layer</span>

# %% [markdown]
# ### Helper Function

# %%
def tf_nan_mean(x, axis=0):
    #calculates the mean of a TensorFlow tensor x along a specified axis while ignoring any NaN values in the tensor.
    return tf.reduce_sum(tf.where(tf.math.is_nan(x), tf.zeros_like(x), x), axis=axis) / tf.reduce_sum(tf.where(tf.math.is_nan(x), tf.zeros_like(x), tf.ones_like(x)), axis=axis)

# %%
def right_hand_percentage(x):
    #calculates percentage of right hand usage
    right = tf.gather(x, RIGHT_HAND, axis=1)
    left = tf.gather(x, LEFT_HAND, axis=1)
    right_count = tf.reduce_sum(tf.where(tf.math.is_nan(right), tf.zeros_like(right), tf.ones_like(right)))
    left_count = tf.reduce_sum(tf.where(tf.math.is_nan(left), tf.zeros_like(left), tf.ones_like(left)))
    return right_count / (left_count+right_count)

# %% [markdown]
# ### <span style="color:green">In the following cell copy + paste the pre-processing layer from Franziska's notebook (,if you added / changed something)</span>

# %%
#generating preprocessing layer that will be added to final model
class FeatureGen(tf.keras.layers.Layer):
    #defines custom tensorflow layer 
    def __init__(self):
        #initializes layer
        super(FeatureGen, self).__init__()
    
    def call(self, x_in, MIRROR=False):
        #drop z coordinates if required
        if DROP_Z:
            x_in = x_in[:, :, 0:2]
        if MIRROR:
            #flipping x coordinates
            x_in = np.array(x_in)
            x_in[:, :, 0] = (x_in[:, :, 0]-1)*(-1)
            x_in = tf.convert_to_tensor(x_in)

        #generates list with mean values for landmarks that will be merged
        x_list = [tf.expand_dims(tf_nan_mean(x_in[:, av_set[0]:av_set[0]+av_set[1], :], axis=1), axis=1) for av_set in averaging_sets]
        
        #extracts specific columns from input x_in defined by landmarks
        handedness = right_hand_percentage(x_in)
        if handedness > 0.5:
            x_list.append(tf.gather(x_in, point_landmarks_right, axis=1))
        else: 
            x_list.append(tf.gather(x_in, point_landmarks_left, axis=1))

        #concatenates the two tensors from above along axis 1/columns
        x = tf.concat(x_list, 1)

        #padding to desired length of sequence (defined by LENGTH)
        #get current number of rows
        x_padded = x
        current_rows = tf.shape(x_padded)[0]
        #if current number of rows is greater than desired number of rows, truncate excess rows
        if current_rows > LENGTH:
            x_padded = x_padded[:LENGTH, :, :]

        #if current number of rows is less than desired number of rows, add padding
        elif current_rows < LENGTH:
            #calculate amount of padding needed
            pad_rows = LENGTH - current_rows

            if PADDING ==4: #copy first/last frame
                if pad_rows %2 == 0: #if pad_rows is even
                    padding_front = tf.repeat(x_padded[0:1, :], pad_rows//2, axis=0)
                    padding_back = tf.repeat(x_padded[-1:, :], pad_rows//2, axis=0)
                else: #if pad_rows is odd
                    padding_front = tf.repeat(x_padded[0:1, :], (pad_rows//2)+1, axis=0)
                    padding_back = tf.repeat(x_padded[-1:, :], pad_rows//2, axis=0)
                x_padded = tf.concat([padding_front, x_padded, padding_back], axis=0)
            elif PADDING == 5: #copy last frame
                padding_back = tf.repeat(x_padded[-1:, :], pad_rows, axis=0)
                x_padded = tf.concat([x_padded, padding_back], axis=0)
            else:
                if PADDING ==1: #padding at start and end
                    if pad_rows %2 == 0: #if pad_rows is even
                        paddings = [[pad_rows//2, pad_rows//2], [0, 0], [0, 0]]
                    else: #if pad_rows is odd
                        paddings = [[pad_rows//2+1, pad_rows//2], [0, 0], [0, 0]]
                elif PADDING ==2: #padding only at the end of sequence
                    paddings = [[0, pad_rows], [0, 0], [0, 0]]
                elif PADDING ==3: #no padding
                    paddings = [[0, 0], [0, 0], [0, 0]]
                x_padded = tf.pad(x_padded, paddings, mode='CONSTANT', constant_values=CONSTANT_VALUE)

        x = x_padded
        current_rows = tf.shape(x)[0]

        #interpolate single missing values
        x = pd.DataFrame(np.array(x).flatten()).interpolate(method='linear', limit=2, limit_direction='both')
        #fill missing values with zeros
        x = tf.where(tf.math.is_nan(x), tf.zeros_like(x), x)
        
        #reshape data to 2D or 3D array
        if FLATTEN:
            x = tf.reshape(x, (1, current_rows*INPUT_SHAPE[1]))
        else:
            x = tf.reshape(x, (1, current_rows, INPUT_SHAPE[1]))

        return x

#define converter using generated layer
feature_converter = FeatureGen()

# %% [markdown]
# ## Real Time Prediction / Detection

# %% [markdown]
# Press "Q" to interrupt the camera feed.

# %%
# 1. New detection variables 
sequence = [] # to collect all 22 frames for prediction
sentence = [] # history of all predictions (predicted words)
predictions = []
threshold = 0.2 # confidence metrics (only render prediction results, if confidence is above threshold)

cap = cv2.VideoCapture(1) # grabbing webcam

# set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic: 
    while cap.isOpened(): # loop through all frames 

        # read feed
        ret, frame = cap.read()
        #frame = cv2.flip(frame, 0) # maybe we need to flip the image? 

        # make detections 
        image, results = mediapipe_detection(frame, holistic)
        #print(results)

        #draw_landmarks(image, results)
        draw_styled_landmarks(image, results)

        # 2. Prediction logic
        keypoints = extract_keypoints(results) # extract keypoints x, y, z for face, left_hand, pose, right_hand from mediapipe holistic predictions, keypoints.shape e.g. (543, 3)
        sequence.append(keypoints) # keep appending keypoints (frames) to a sequence, np.array(sequence).shape e.g. (22, 543, 3)
        sequence = sequence[-LENGTH:] # takes last LENGTH frames of the sequence

        # 
        if len(sequence) == LENGTH: 
            # pre-processing
            model_input = feature_converter(np.array(sequence))
            #print(f'OMG! Frenzy Franzi is converting your mediapipe input! See how the shape is changing from {np.array(sequence).shape} to {model_input.shape}! SO AWESOME!!!')
            
            # prediction
            pred = model.predict(model_input)[0] # model.fit() expects something in shape (num_sequences, 30, 1662), e.g. (1, 30, 1662) for a single sequence
            selected_labels = [LABEL_MAP[x] for x in SELECTED_SIGNS]
            pred_all = pred 
            pred = pred[selected_labels]
            predictions.append(np.argmax(pred))

            # 3. Visualization logic
            # makes sure the last x frames had the same prediction (more stable transition from one sign to another) 
            if np.unique(predictions[-TRANSITION_FRAMES:])[0]==np.argmax(pred): 
                # if the confidence of the most confident prediction is above threshold
                if pred[np.argmax(pred)] > threshold: 
                    # if there is already a last prediction
                    if len(sentence) > 0: 
                        # only append the predicted word, if it differs from the last prediction (prevent double actions)
                        if SELECTED_SIGNS[np.argmax(pred)] != sentence[-1]: 
                            sentence.append(SELECTED_SIGNS[np.argmax(pred)])
                    # just append if there is no last prediction (first prediction)
                    else: 
                        sentence.append(SELECTED_SIGNS[np.argmax(pred)])

            # limit the history to the last 5 predictions
            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # viz probabilities
            print(f'Example prediction for "{SELECTED_SIGNS[np.argmax(pred)]}": {pred[np.argmax(pred)]}')
            image = prob_viz(pred, image, SELECTED_SIGNS)

        # some rendering
        cv2.rectangle(image, (0, 0), (1280, 60), (200, 200, 200), -1)
        cv2.putText(image, ' '.join(sentence), (45, 45), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (52, 75, 102), 1, cv2.LINE_AA)
        # cv2.putText(image, 'OpenCV', org, font, fontScale, color, thickness, cv2.LINE_AA)

        # show to screen
        cv2.imshow("OpenCV Feed", image)

        # break gracefully 
        if cv2.waitKey(10) & 0xFF == ord('q'): 
            break 
        
# release camera and close feed window 
cap.release()
cv2.destroyAllWindows() 
cv2.waitKey(1) # some workaround to fix the bug, that window doesn't close
# Out:
# 1/1 [==============================] - 0s 286ms/step
# Example prediction for "tomorrow": 0.9999982118606567
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999967813491821
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999955892562866
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999890327453613
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999812841415405
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "tomorrow": 0.9999701976776123
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999690055847168
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999566078186035
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999438524246216
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999358654022217
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999455213546753
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999415874481201
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999336004257202
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999915599822998
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9998911619186401
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998728036880493
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.9998620748519897
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998262524604797
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998409748077393
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998238682746887
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998977184295654
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.999885082244873
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999136924743652
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999123811721802
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999444484710693
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999411106109619
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999575614929199
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999572038650513
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999643564224243
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "tomorrow": 0.9999687671661377
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.999976396560669
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999806880950928
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999778270721436
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999981164932251
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999785423278809
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999803304672241
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999836683273315
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999887943267822
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999898672103882
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999877214431763
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999849796295166
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999802112579346
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999829530715942
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999804496765137
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999833106994629
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999871253967285
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999897480010986
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.99998939037323
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.999988317489624
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999874830245972
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999852180480957
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999841451644897
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999814033508301
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999977707862854
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999738931655884
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.999975323677063
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999755620956421
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999812841415405
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999923706054688
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999971389770508
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999864101409912
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999853372573853
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999954700469971
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999756813049316
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9995501637458801
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9991852641105652
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9993428587913513
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997361302375793
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9996837377548218
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9950684309005737
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9592930674552917
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9824371337890625
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9968106150627136
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9886226058006287
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9277647733688354
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9572615027427673
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9971265196800232
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9980486631393433
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999415397644043
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9990860223770142
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9988614320755005
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9987291693687439
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9960946440696716
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.9878343343734741
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9888261556625366
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9888413548469543
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9919734001159668
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9950340986251831
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9960075616836548
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9962812066078186
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9986231327056885
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9996047616004944
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9997314810752869
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9993091821670532
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9986101388931274
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9988448619842529
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9989725351333618
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9986143112182617
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9969057440757751
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9975513815879822
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9984851479530334
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9992311000823975
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9992082715034485
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9991154074668884
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999196469783783
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999286949634552
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9993230104446411
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9993613362312317
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9989964365959167
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9987682700157166
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9984340071678162
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9981666803359985
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9985761642456055
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9982594847679138
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9978868365287781
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9980871677398682
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9991233944892883
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.9993728995323181
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9993283748626709
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9991397857666016
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9991244673728943
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9993911981582642
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9994237422943115
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9993364214897156
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999131977558136
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9990322589874268
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9992978572845459
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9944519400596619
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.8231961131095886
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7306140661239624
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.5291086435317993
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.9664953947067261
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.9550178050994873
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.9292109608650208
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.8198416829109192
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.5970546007156372
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.987251877784729
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999840259552002
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "tomorrow": 0.9998636245727539
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9008561968803406
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "minemy": 0.6347286701202393
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5093721151351929
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.6871556043624878
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.6297622323036194
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7197418212890625
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7224645614624023
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.6779220700263977
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9842193722724915
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999369382858276
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999737739562988
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999904632568359
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999980926513672
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.99997878074646
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999885559082031
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999843835830688
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999887943267822
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999969005584717
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999995231628418
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999997615814209
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999984502792358
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.6342614889144897
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.8816941976547241
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.7970753312110901
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.8563151359558105
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.8516953587532043
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "who": 0.7860024571418762
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9853523373603821
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.8902282118797302
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9854565262794495
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9979678988456726
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999853372573853
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "icecream": 0.8829290270805359
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.8620947003364563
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999679327011108
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9569228887557983
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9985338449478149
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9741368293762207
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.6595842838287354
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9471939206123352
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9516547322273254
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999701976776123
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998629093170166
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998881816864014
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999004602432251
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999771118164062
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999831914901733
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999895095825195
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999902248382568
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999933242797852
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999967813491821
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999982118606567
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999986886978149
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999879598617554
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9996776580810547
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997742772102356
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995970129966736
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999662637710571
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999990463256836
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998905658721924
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997276663780212
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9988065958023071
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9123138189315796
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.7270060777664185
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.8581193089485168
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.6652352809906006
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.37384191155433655
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999332427978516
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9802350997924805
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999971389770508
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9988099336624146
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7964245080947876
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.5509791970252991
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9988774657249451
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9979866743087769
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9675900340080261
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.8207855224609375
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "minemy": 0.619276225566864
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999822199344635
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999997615814209
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999997615814209
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999425411224365
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.8754624128341675
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.9641730189323425
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.711601197719574
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7559434771537781
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.5636210441589355
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "please": 0.7948106527328491
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9112694263458252
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999249279499054
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997525811195374
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999935626983643
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999990463256836
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999958276748657
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.999765932559967
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9159898161888123
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "please": 0.8807794451713562
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.6080889701843262
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9915743470191956
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995602965354919
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9996566772460938
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999955892562866
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999997615814209
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999997615814209
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999997615814209
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999997615814209
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999997615814209
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999997615814209
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999997615814209
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999995231628418
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999995231628418
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999995231628418
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999994039535522
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999994039535522
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.9999995231628418
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999995231628418
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999997615814209
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999997615814209
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999994039535522
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999990463256836
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999984502792358
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.9999966621398926
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999914169311523
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.999980092048645
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999535083770752
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "tomorrow": 0.9999667406082153
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999972581863403
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 1.0
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999998807907104
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999996423721313
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "tomorrow": 0.9999986886978149
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999971389770508
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999957084655762
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "tomorrow": 0.9999910593032837
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "tomorrow": 0.9999932050704956
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "tomorrow": 0.9999905824661255
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.9999984502792358
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "tomorrow": 0.9999990463256836
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "tomorrow": 0.9999980926513672
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999979734420776
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "tomorrow": 0.9999978542327881
# 1/1 [==============================] - 0s 17ms/step
# Example prediction for "tomorrow": 0.9999942779541016
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999927282333374
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999809265136719
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999967098236084
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999607801437378
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9998995065689087
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9998908042907715
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998452663421631
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999763548374176
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997150301933289
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9997966885566711
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9994569420814514
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9990880489349365
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999085545539856
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9988375306129456
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9992817044258118
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9996263980865479
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9996533393859863
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.999561607837677
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.9994895458221436
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "tomorrow": 0.9993104934692383
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.9992440938949585
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9989573955535889
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999483585357666
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.999639630317688
# 1/1 [==============================] - 0s 16ms/step
# Example prediction for "tomorrow": 0.9997273087501526
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9995396137237549
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.99943608045578
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9993230104446411
# 1/1 [==============================] - 0s 48ms/step
# Example prediction for "tomorrow": 0.9991738200187683
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9994051456451416
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9995808005332947
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9996275901794434
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995419979095459
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.999661922454834
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997650980949402
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9998565912246704
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999257326126099
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999567270278931
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999195337295532
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9998724460601807
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9996490478515625
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997021555900574
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9996721744537354
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9997504353523254
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997037053108215
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9996471405029297
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995891451835632
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995490908622742
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9993282556533813
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9992685914039612
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9991951584815979
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9989301562309265
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9982500672340393
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9961095452308655
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9913175106048584
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9908696413040161
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9943777918815613
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9967705011367798
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9987271428108215
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9994483590126038
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999678373336792
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999607264995575
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9993602633476257
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.9990339279174805
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.998426079750061
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9984166622161865
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9984410405158997
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9989013671875
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999272882938385
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9994877576828003
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9994727969169617
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999277651309967
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.998921275138855
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9984984397888184
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.997686505317688
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9965364933013916
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9951752424240112
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9935610294342041
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9935203194618225
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9950318336486816
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9963397979736328
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9981348514556885
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9987242817878723
# 1/1 [==============================] - 0s 11ms/step
# ...
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9996182918548584
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997158646583557
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995433688163757
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995651841163635
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9989396929740906
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9990197420120239
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999123752117157
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9994577765464783
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995858073234558
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9996534585952759
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9996919631958008
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995406866073608
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9991475343704224
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9987610578536987
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9990392923355103
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9991945624351501
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9993857145309448
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9992332458496094
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9989511966705322
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9989927411079407
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9992857575416565
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9992882609367371
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9991471767425537
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999029278755188
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9991927742958069
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9988518953323364
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9992513060569763
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995841383934021
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997829794883728
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997990727424622
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.999815046787262
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997877478599548
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997484087944031
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997005462646484
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9996731281280518
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9995830655097961
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995348453521729
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999618649482727
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997524619102478
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998302459716797
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998823404312134
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999039173126221
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999094009399414
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999029636383057
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999109506607056
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999094009399414
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998779296875
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9998464584350586
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997839331626892
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997554421424866
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997374415397644
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997171759605408
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997947812080383
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997817873954773
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998117089271545
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998576641082764
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999444484710693
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999788999557495
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999855756759644
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999833106994629
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999359846115112
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998729228973389
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999871015548706
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999494552612305
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999231100082397
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999908447265625
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999067783355713
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9998700618743896
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997177720069885
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9994909763336182
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995213747024536
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9997860789299011
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999620914459229
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999750852584839
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999730587005615
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999167919158936
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.9998414516448975
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995693564414978
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9990905523300171
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9982969164848328
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9983358979225159
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9993923902511597
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999234676361084
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999417066574097
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999963641166687
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999159574508667
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999314546585083
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999452829360962
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999474287033081
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999550580978394
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999382495880127
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999924898147583
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999290704727173
# 1/1 [==============================] - 0s 10ms/step
# Example prediction for "tomorrow": 0.9999591112136841
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999792575836182
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999873638153076
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999914169311523
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999698400497437
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999394416809082
# 1/1 [==============================] - 0s 13ms/step
# Example prediction for "tomorrow": 0.9999297857284546
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999328851699829
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999374151229858
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999346733093262
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999593496322632
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999945878982544
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999487400054932
# 1/1 [==============================] - 0s 15ms/step
# Example prediction for "tomorrow": 0.9999350309371948
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "tomorrow": 0.9999427795410156
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "tomorrow": 0.9999450445175171
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999591112136841
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999574422836304
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999610185623169
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999094009399414
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999915361404419
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998445510864258
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999033212661743
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999186992645264
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999439716339111
# 1/1 [==============================] - 0s 14ms/step
# Example prediction for "tomorrow": 0.9999428987503052
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999420642852783
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999547004699707
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999375343322754
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999395608901978
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999417066574097
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999761581420898
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999896287918091
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999959468841553
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999966621398926
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999974966049194
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999970197677612
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999960660934448
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999993085861206
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999821186065674
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999698400497437
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999217987060547
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998251795768738
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9996681213378906
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9996193647384644
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999750554561615
# 1/1 [==============================] - 0s 12ms/step
# Example prediction for "tomorrow": 0.9999282360076904
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999607801437378
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.999962568283081
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9999475479125977
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9998629093170166
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9995784163475037
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9991975426673889
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9987525939941406
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9982056617736816
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9985706806182861
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9988998174667358
# 1/1 [==============================] - 0s 11ms/step
# Example prediction for "tomorrow": 0.9989953637123108
# -1

# %% [markdown]
# ## Next steps
#
# Save the recordings and predictions for later use?
#
# Add a feature, so that the user can type into a textbox to correct wrong prediction + real-time training / update of the model?
